# %% [markdown]
# ## Conecciones con pandas y MySQL
#
# Generalmente en las organizaciones los datos se encuentran en Bases de datos que pueden ser estructuradas (MySQL, MariaDB, SQL Server, PostgreSQL, etc) y no estructuradas (MongoDB, Dynamo DB, etc), en la sesion de hoy trabajaremos con Conecciones a MySQL

# %% [markdown]
# <img src = https://www.scylladb.com/wp-content/uploads/nosql-design-principles-diagram.png>

# %%
# !pip install mysql-connector-python
# Out:
# Collecting mysql-connector-python
#   Downloading mysql_connector_python-8.1.0-cp310-cp310-manylinux_2_17_x86_64.whl (27.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.5/27.5 MB 42.9 MB/s eta 0:00:00
# Collecting protobuf<=4.21.12,>=4.21.1 (from mysql-connector-python)
#   Downloading protobuf-4.21.12-cp37-abi3-manylinux2014_x86_64.whl (409 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 409.8/409.8 kB 29.6 MB/s eta 0:00:00
# Installing collected packages: protobuf, mysql-connector-python
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-metadata 1.14.0 requires protobuf<4.21,>=3.20.3, but you have protobuf 4.21.12 which is incompatible.
# Successfully installed mysql-connector-python-8.1.0 protobuf-4.21.12

# %%
import mysql.connector
import pandas as pd
# Define the connection string (assuming a typical localhost setup for demonstration)
connection_string = {
    'user' : 'doadmin',
    'password' : 'AVNS_sAMuAiwTX_UzEy6cR63',
    'host' : 'db-ro-mysql-nyc1-25804-do-user-13295890-0.b.db.ondigitalocean.com',
    'port' : 25060,
    'database' :'defaultdb'
}

# Establish the connection
connection = mysql.connector.connect(**connection_string)

# Check if connection is established
if connection.is_connected():
    print("Connected to MySQL server")
    df = pd.read_sql("SELECT*FROM ejercicio1",connection)
    connection.close()
else:
    print("Failed to connect")
# Out:
# Connected to MySQL server
# /tmp/ipykernel_7090/362035115.py:18: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql("SELECT*FROM ejercicio1",connection)

# %%
df
df.drop('ID_Venta', axis = 1)
# Out:
#       Categoria Hora_Dia  Unidades_Vendidas  Ingresos
# 0   Electrónica    Tarde                 15   317.000
# 1       Muebles    Noche                 17   441.845
# 2          Ropa   Mañana                  2   397.534
# 3   Electrónica   Mañana                  9   291.439
# 4       Muebles    Noche                  1   370.833
# ..          ...      ...                ...       ...
# 95  Electrónica    Tarde                  7   237.442
# 96    Alimentos    Tarde                  8   415.549
# 97      Muebles   Mañana                 19   264.549
# 98         Ropa   Mañana                 12   243.709
# 99  Electrónica   Mañana                 18   259.800
#
# [100 rows x 4 columns]

# %%
df.groupby("Hora_Dia").sum()
# Out:
# <ipython-input-39-3059562688f4>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby("Hora_Dia").sum()
#           ID_Venta  Unidades_Vendidas   Ingresos
# Hora_Dia
# Mañana        2049                327  11598.100
# Noche         1813                367  11500.325
# Tarde         1188                271   7678.368

# %%
categorias = ['Electrónica', 'Ropa', 'Alimentos', 'Muebles']
hora_dia = ['Mañana', 'Tarde', 'Noche']
n = 100
df = pd.DataFrame({
    'ID_Venta': np.arange(1, n + 1),
    'Categoria': np.random.choice(categorias, n),
    'Hora_Dia': np.random.choice(hora_dia, n),
    'Unidades_Vendidas': np.random.randint(1, 20, n),
    'Ingresos': np.random.uniform(100, 500, n)
})
df.head()
# Out:
#    ID_Venta    Categoria Hora_Dia  Unidades_Vendidas    Ingresos
# 0         1         Ropa    Tarde                 11  159.589948
# 1         2  Electrónica    Noche                 11  149.097926
# 2         3  Electrónica   Mañana                 10  485.565196
# 3         4    Alimentos    Tarde                  4  221.368505
# 4         5  Electrónica   Mañana                 12  206.672073
