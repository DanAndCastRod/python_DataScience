# %% [markdown]
# # Introducción a Web Scraping con Python
#
# ![img](https://miro.medium.com/v2/resize:fit:1400/1*1QcqrOoDE1rKa0NTp1iEtw.png)
#
# ## ¿Qué es el Web Scraping?
#
# El web scraping es una técnica utilizada para extraer datos de sitios web. Se lleva a cabo mediante programas que simulan la navegación de un humano en la web, recolectando información espcífica de páginas web automáticamente. Esta técnica es especialmente útil para procesar grandes cantidades de datos que sería impráctico o muy tedioso recolectar a mano. [Diferencias entre web scraping y web crawling](https://www.geeksforgeeks.org/difference-between-web-scraping-and-web-crawling/?ref=gcse)
#
# ## Aplicaciones del Web Scraping
#
# 1. **Análisis de Datos y Business Intelligence:** Empresas utilizan el web scraping para recopilar datos de mercado, competidores, precios, y opiniones de clientes, lo que les ayuda en la toma de decisiones y estrategias de negocio.
#
# 2. **Monitoreo de Medioa y Redes Sociales:** Se utilizar para seguir menciones de una marca, producto o tema en específico en diferentes plataformas y sitios de noticia.
#
# 3. **Recopilación de datos para investigaciones Académicas:** Investigadores en diversas áreas recurren al web scraping para reunir grandes volumenes de datos de fuentes públicas para sus estudios.
#
# 4. **SEO y Marketing:** Para analizar el posicionamiento web, backlinks y rendimiento de palabras clave en diferentes sitios.
#
# 5. **Automatización y Agregación de contenidos:** Recopilar información de distintos sitios web y representarla en un solo lugar, como en el caso de agregadores de noticias o comparadores de precios.
#
# ## Limitaciones éticas y legales.
#
# 1. **Violación de los Términos de Servicio:** Algunos sitios web prohíben expresamente el web scraping en sus términos de servicio. Ignorar estas restricciones puede llevar a acciones legales.
#
# 2. **Privacidad y Protección de Datos:** Es crucial respetar las leyes de protección de datos, como el GDPR en europa. Extraer datos personales sin consentimiento puede ser ilegal.
#
# 3. **Carga en los Servidores Web:** El scraping intensivo puede sobrecargar los servidores del sitio web objetivo, afectando su funcionamiento y causando problemas de servicio.
#
# 4. **Uso de Datos Recolectados:** El uso comercial o la distribución de datos obtenidos mediante scraping puede infringir los derechos de autor o marcas registradas.
#
# ## Diferencias entre Web Scraping y API
#
# * **Web Scraping:** Implica extraer datos directamente del HTML o contenido de un sitio web. Es una técnica no estructurada y puede requerir adaptación si la estructura del sitio web cambia. No siempre es autorizado por el propietario del sitio web.
#
# * **API (Interfaz de Programación de Aplicaciones):** Es un medio proporcionado por el sitio web para que terceros accesdan a sus datos de manera controlada y estructurada. Las API son una forma oficial y generalmente autorizada para acceder a los datos, con limitaciones y estructuras definidas por el proveedor del servicio.
#
# En conclusion, el web scraping es una forma más libre pero potencialmente problemática de obtener los datos, mientras que las API ofrecen un camino oficial y estructurado para acceder a ellos.

# %% [markdown]
# # Herramientas y bibliotecas
#
# Para hacer web scraping desde python, existen varias herramientas y bibliotecas disponibles que facilitan el proceso.
#
# ## 1. BeautifulSoup [Pypi Docs](https://pypi.org/project/beautifulsoup4/)
#
#
#
# Beautiful Soup es una biblioteca que facilita la extracción de información de páginas web. Se asienta sobre un analizador HTML o XML, lo que proporciona modismos de Pythonic para iterar, buscar y modificar el árbol de análisis.
#
# * **Uso**
#
#   Para parsear HTML y XML. Es excelente para tareas de scraping donde se necesitan extraer datos de páginas con estructuras completas
#
# * **Ventajas**
#
#   Es fácil de usar, potente para parsear documentos, y funciona bien con diferentes parsers como `lxml` y `html5lib`
#
# ***Parsear*** *es el proceso de analizar una secuencia de símbolos a fin de determinar su estructura gramatical definida. También llamado análisis de sintaxis.*

# %%
# !pip install bs4
# Out:
# Installing collected packages: bs4
# Successfully installed bs4-0.0.1

# %% [markdown]
# ## 2. Requests [Pypi Docs](https://pypi.org/project/requests/)
# Requests le permite enviar solicitudes HTTP/1.1 de forma extremadamente sencilla. No hay necesidad de agregar manualmente cadenas de consulta a sus URL o codificar sus datos
#
# * **Uso:**
#
#   Se usa principalmente para realizar solicitudes HTTP en Python. A menudo se usa junto con BeutifulSoup para descargar páginas web antes de parsearlas.
#
# * **Ventajas:**
#
#   Simple y fácil de usar, gestiona sesiones, soporta persistent connections, y tiene soporte para SSL.
#
# Requests está preparado para las demandas de creación de aplicaciones HTTP robustas y confiables, para las necesidades de hoy en día.
#
#
#
# * Keep-Alive y agrupación de conexiones
#
# * Dominios y URLs Internacionales
#
# * Sesiones con persistencia de cookies
#
# * Verificación TLS/SSL al estilo del navegador
#
# * Autenticación básica y implícita
#
# * Familiar –como las cookiesdict
#
# * Descompresión y decodificación automáticas de contenido
#
# * Carga de archivos de varias partes
#
# * Soporte de proxy SOCKS
#
# * Tiempos de espera de conexión
#
# * Descargas de streaming
#
# * Honra automática de .netrc
#
# * Solicitudes HTTP fragmentadas
#
#
# [Readthedocs](https://requests.readthedocs.io/en/latest/)

# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2023.7.22)

# %% [markdown]
# ## 3. Scrapy [Pypi Docs](https://pypi.org/project/Scrapy/)
#
# Scrapy es un marco rápido de rastreo web y raspado web de alto nivel, que se utiliza para Rastrea sitios web y extrae datos estructurados de sus páginas. Se puede utilizar para una amplia gama de propósitos, desde la minería de datos hasta el monitoreo y las pruebas automatizadas.
#
# * **Uso**
#
#   Es un framework de web scraping y crawling. Ideal para proyectos de scraping a gran escala.
#
# * **Ventajas**
#
#   Maneja requests y follow-ups de manera eficiente, soporta scraping de múltiples páginas, y es altamente personalizable.
#
#
# [Docs](https://scrapy.org/)

# %%
# !pip install scrapy

# %% [markdown]
# ## 4. Selenium [Pypi Docs](https://pypi.org/project/selenium/)
#
# El paquete selenium se utiliza para automatizar la interacción del navegador web desde Python.
#
# * **Uso**
#
#   Para automatizar navegadores web. Muy útil para sitios web que requieren interacciones más complejas, como har clic en botones o llenar formularios.
#
# * **Ventajas**
#
#   Maneja requests y follow-ups de manera eficiente, soporta scraping de múltiples páginas, y es altamente personalizable.
# [Docs](https://www.selenium.dev/)

# %%
# !pip install selenium
# Out:
# Collecting selenium
#   Downloading selenium-4.15.2-py3-none-any.whl (10.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 43.9 MB/s eta 0:00:00
# Requirement already satisfied: urllib3[socks]<3,>=1.26 in /usr/local/lib/python3.10/dist-packages (from selenium) (2.0.7)
# Collecting trio~=0.17 (from selenium)
#   Downloading trio-0.23.1-py3-none-any.whl (448 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 448.3/448.3 kB 42.4 MB/s eta 0:00:00
# Collecting trio-websocket~=0.9 (from selenium)
#   Downloading trio_websocket-0.11.1-py3-none-any.whl (17 kB)
# Requirement already satisfied: certifi>=2021.10.8 in /usr/local/lib/python3.10/dist-packages (from selenium) (2023.7.22)
# Requirement already satisfied: attrs>=20.1.0 in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (23.1.0)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (3.4)
# Collecting outcome (from trio~=0.17->selenium)
#   Downloading outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: sniffio>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (1.3.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (1.1.3)
# Collecting wsproto>=0.14 (from trio-websocket~=0.9->selenium)
#   Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Collecting h11<1,>=0.9.0 (from wsproto>=0.14->trio-websocket~=0.9->selenium)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 8.0 MB/s eta 0:00:00
# Installing collected packages: outcome, h11, wsproto, trio, trio-websocket, selenium
# Successfully installed h11-0.14.0 outcome-1.3.0.post0 selenium-4.15.2 trio-0.23.1 trio-websocket-0.11.1 wsproto-1.2.0

# %% [markdown]
# ## Herramientas Adicionales.
#
# * **DevTools:** para inspeccionar elementos de una página web y entender su estructura.
#
# * **Proxy Services:** Como [ScraperAPI](https://www.scraperapi.com/), para manejar bloqueos de IP o captchas.
#
# * **Rotating User Agents:** Para evitar ser bloqueado por sitios web al imitar ser diferentes navegadores.

# %% [markdown]
# # Fundamentos HTML y CSS

# %% [markdown]
# ## Estructura de un HTML
#
# ```{html}
# <!DOCTYPE html>
# <html>
#   <head></head>
#   <body>
#     <nav></nav>
#     <main></main>
#     <footer></footer>
#   </body>
# </html>
# ```
#
# ### Elementos Más Usados en HTML
#
# En HTML, varios elementos son ampliamente utilizados debido a su funcionalidad y flexibilidad. Algunos de los más comunes incluyen:
#
# 1. **`<div>`**: Este es probablemente el elemento más utilizado en HTML. Sirve como un contenedor genérico para contenido de flujo y es usado frecuentemente para agrupar elementos para propósitos de estilos o scripting.
#
# 2. **`<span>`**: Similar al `<div>`, pero se usa para agrupar elementos en línea. Es útil para aplicar estilos o scripts a una parte específica del texto.
#
# 3. **`<a>`**: Representa un hiperenlace, que se utiliza para enlazar a otra página o recurso.
#
# 4. **`<p>`**: Define un párrafo de texto. Es un bloque de texto que suele estar separado por espacios o saltos de línea de los bloques adyacentes.
#
# 5. **`<ul>`, `<ol>`, `<li>`**: Estos elementos se utilizan para listas. `<ul>` es para listas desordenadas, `<ol>` para listas ordenadas y `<li>` para cada ítem de la lista.
#
# 6. **`<img>`**: Se utiliza para insertar imágenes. Es un elemento fundamental para añadir contenido visual a la web.
#
# 7. **`<h1>` a `<h6>`**: Estos son elementos de encabezado. `<h1>` es el más importante (generalmente el título de la página o post) y `<h6>` el menos.
#
# 8. **`<table>`, `<tr>`, `<td>`**: Utilizados para crear tablas. `<table>` define la tabla, `<tr>` una fila y `<td>` una celda.
#
# 9. **`<form>`**: Para formularios que permiten al usuario introducir datos. Elementos como `<input>`, `<label>`, `<textarea>`, y `<button>` se utilizan dentro de un `<form>`.
#
# 10. **`<input>`**: Un elemento versátil para crear diferentes tipos de campos de entrada, como texto, contraseña, radio buttons, checkboxes, etc.
#
# ### Árbol del DOM
#
# El Document Object Model (DOM) es una representación de la estructura de una página web. Imagina la página web como un árbol, donde cada elemento HTML es un nodo.
#
# - **Nodos**: Cada parte del documento, como elementos, atributos, e incluso texto, son nodos en el DOM. Por ejemplo, `<body>` es un nodo, y todos los elementos dentro de `<body>` son nodos hijos de `<body>`.
#
# - **Relaciones Padre-Hijo**: Los elementos anidados crean una relación padre-hijo en el DOM. Por ejemplo, si tienes un `<div>` que contiene varios `<p>`, el `<div>` es el nodo padre y los `<p>` son nodos hijos.
#
# - **Propósito del DOM**: Permite a los lenguajes de programación interactuar con la estructura, estilo y contenido de los sitios web. Por ejemplo, con JavaScript, puedes usar el DOM para añadir, eliminar o modificar elementos HTML, cambiar estilos CSS, y responder a eventos en la página.
#
# El DOM es fundamental en web scraping porque cuando utilizas herramientas como BeautifulSoup o Selenium, en esencia estás interactuando con el DOM para extraer información o realizar acciones en la página web.

# %% [markdown]
# ## Inspección de Elementos con el Navegador

# %% [markdown]
# ## Selección de Datos Usando Selectores CSS
#
# Los selectores CSS son patrones utilizados para seleccionar los elementos HTML que quieres estilizar. En el contexto del web scraping, estos selectores son igualmente cruciales para identificar y extraer datos específicos de una página web.
#
# ### Tipos de Selectores
#
# #### 1. **Selectores de Etiqueta**
#    - **Descripción**: Seleccionan elementos por su nombre de etiqueta.
#    - **Ejemplo**: `p` seleccionará todos los elementos `<p>` en un documento.
#
# #### 2. **Selectores de Clase**
#    - **Descripción**: Seleccionan elementos por su atributo de clase.
#    - **Ejemplo**: `.menu` seleccionará todos los elementos que tienen la clase `menu`.
#
# #### 3. **Selectores de ID**
#    - **Descripción**: Seleccionan un único elemento que tiene un atributo de ID específico.
#    - **Ejemplo**: `#header` seleccionará el elemento que tiene el ID `header`.
#
# ### Selectores Avanzados
#
# #### 1. **Selectores Descendientes**
#    - **Descripción**: Seleccionan todos los elementos que son descendientes de un elemento especificado.
#    - **Ejemplo**: `div p` seleccionará todos los elementos `<p>` que están dentro de un `<div>`.
#
# #### 2. **Selectores de Hijos**
#    - **Descripción**: Seleccionan todos los elementos hijos directos de un elemento especificado.
#    - **Ejemplo**: `ul > li` seleccionará todos los elementos `<li>` que son hijos directos de un `<ul>`.
#
# #### 3. **Selectores de Atributos**
#    - **Descripción**: Seleccionan elementos basados en un atributo y valor específicos.
#    - **Ejemplo**: `[type="text"]` seleccionará todos los elementos que tienen un atributo `type` con el valor `text`.
#
# ### Utilización en Web Scraping
#
# En web scraping, estos selectores se utilizan para identificar los elementos de los cuales quieres extraer datos. Por ejemplo, si estás usando BeautifulSoup en Python, puedes usar estos selectores para encontrar elementos específicos:
#
# ```python
# soup.find_all('p') # Usando un selector de etiqueta
# soup.select('.menu') # Usando un selector de clase
# soup.select('#header') # Usando un selector de ID
# ```
#
# Estos selectores son fundamentales para el scraping efectivo, ya que te permiten apuntar a datos específicos dentro de una estructura HTML compleja. La precisión y eficacia del scraping dependen en gran medida de qué tan bien se utilicen estos selectores para navegar por el DOM.

# %% [markdown]
# # Ejemplos de uso

# %% [markdown]
# Hagamos un ejercicio sencillo para extraer la información de noticias de la página oficial de BBC

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
from fake_useragent import UserAgent
url = 'https://www.bbc.com/news/world'
user_agent = UserAgent()
response = requests.get(url, headers = {'user-agent':user_agent.edge})
if response.status_code == 200:
    html_content = response.text
else:
    html_content = ""
soup = BeautifulSoup(html_content, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width" name="viewport"/>
#   <title>
#    World - BBC News
#   </title>
#   <meta content="World - BBC News" property="og:title"/>
#   <meta content="World - BBC News" name="twitter:title"/>
#   <meta content="Get the latest BBC World News: international news, features and analysis from Africa, the Asia-Pacific, Europe, Latin America, the Middle East, South Asia, and the United States and Canada." name="description"/>
#   <meta content="Get the latest BBC World News: international news, features and analysis from Africa, the Asia-Pacific, Europe, Latin America, the Middle East, South Asia, and the United States and Canada." property="og:description"/>
#   <meta content="Get the latest BBC World News: international news, features and analysis from Africa, the Asia-Pacific, Europe, Latin America, the Middle East, South Asia, and the United States and Canada." name="twitter:description"/>
#   <meta content="#da532c" name="msapplication-TileColor"/>
#   <meta content="#ffffff" name="theme-color"/>
#   <meta content="noindex, nofollow" name="robots"/>
#   <link href="/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
#   <link href="/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
#   <link href="/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
#   <link href="/favicon.ico" rel="alternate icon"/>
#   <link href="/site.webmanifest" rel="manifest"/>
#   <link color="#000000" href="/safari-pinned-tab.svg" rel="mask-icon"/>
#   <link href="https://www.bbc.com/news/world" rel="canonical"/>
#   <link data-testid="en-hreflang-tag" href="https://www.bbc.com/news/world" hreflang="en" rel="alternate"/>
#   <link data-testid="en-gb-hreflang-tag" href="https://www.bbc.co.uk/news/world" hreflang="en-gb" rel="alternate"/>
#   <meta content="0.17.3+1" name="version"/>
#   <script type="application/ld+json">
#    {"@context":"http://schema.org","@type":"WebPage","description":"Get the latest BBC World News: international news, features and analysis from Africa, the Asia-Pacific, Europe, Latin America, the Middle East, South Asia, and the United States and Canada.","url":"https://www.bbc.com/news/world","mainEntityOfPage":"https://www.bbc.com/news/world","publisher":{"@type":"NewsMediaOrganization","name":"BBC News","logo":"https://m.files.bbci.co.uk/modules/bbc-morph-news-waf-page-meta/5.3.0/bbc_news_logo.png","publishingPrinciples":"https://www.bbc.co.uk/news/help-41670342"},"name":"World - BBC News"}
#   </script>
#   <meta content="22" name="next-head-count"/>
#   <link as="font" crossorigin="anonymous" href="/bbcx/_next/static/media/d5f96954169f3679.p.woff" rel="preload" type="font/woff"/>
#   <link as="font" crossorigin="anonymous" href="/bbcx/_next/static/media/f62d67caf3a51aea.p.woff" rel="preload" type="font/woff"/>
#   <link as="font" crossorigin="anonymous" href="/bbcx/_next/static/media/b5808b4cd433286b.p.woff" rel="preload" type="font/woff"/>
#   <link as="font" crossorigin="anonymous" href="/bbcx/_next/static/media/b3cc10788a0e66eb.p.woff" rel="preload" type="font/woff"/>
#   <link as="font" crossorigin="anonymous" href="/bbcx/_next/static/media/d1557e5f46f77917.p.woff" rel="preload" type="font/woff"/>
#   <link as="font" crossorigin="anonymous" href="/bbcx/_next/static/media/2d4795d021bab986.p.woff" rel="preload" type="font/woff"/>
#   <link as="font" crossorigin="anonymous" href="/bbcx/_next/static/media/48f9d2711a8d7b17.p.woff" rel="preload" type="font/woff"/>
#   <link as="font" crossorigin="anonymous" href="/bbcx/_next/static/media/96161a9bfe151a00.p.woff" rel="preload" type="font/woff"/>
#   <link as="font" crossorigin="anonymous" href="/bbcx/_next/static/media/0d9d619a2d57fba4.p.woff" rel="preload" type="font/woff"/>
#   <link as="font" crossorigin="anonymous" href="/bbcx/_next/static/media/127e830343b9db2c.p.woff" rel="preload" type="font/woff"/>
#   <link as="font" crossorigin="anonymous" href="/bbcx/_next/static/media/5c1db66e66eaee0e.p.woff" rel="preload" type="font/woff"/>
#   <link as="font" crossorigin="anonymous" href="/bbcx/_next/static/media/6bd602911783b8b0.p.woff" rel="preload" type="font/woff"/>
#   <link as="font" crossorigin="anonymous" href="/bbcx/_next/static/media/b36f6bac73b2c645.p.woff" rel="preload" type="font/woff"/>
#   <link as="font" crossorigin="anonymous" href="/bbcx/_next/static/media/7328d574a2e5bccc.p.woff" rel="preload" type="font/woff"/>
#   <link as="font" crossorigin="anonymous" href="/bbcx/_next/static/media/e8223b3afcb82cf6.p.woff" rel="preload" type="font/woff"/>
#   <link as="font" crossorigin="anonymous" href="/bbcx/_next/static/media/b36685b86da40a03.p.woff" rel="preload" type="font/woff"/>
#   <link as="font" crossorigin="anonymous" href="/bbcx/_next/static/media/6de3099f2481c296.p.woff" rel="preload" type="font/woff"/>
#   <link as="font" crossorigin="anonymous" href="/bbcx/_next/static/media/33acc70dd32e194a.p.woff" rel="preload" type="font/woff"/>
#   <link as="font" crossorigin="anonymous" href="/bbcx/_next/static/media/70829e37664a6fd3.p.woff" rel="preload" type="font/woff"/>
#   <link as="font" crossorigin="anonymous" href="/bbcx/_next/static/media/2bd6dac86b11d814.p.woff" rel="preload" type="font/woff"/>
#   <script async="" data-nscript="beforeInteractive" id="inline-dotcom">
#    window.dotcom = window.dotcom || { cmd: [] }; window.dotcomConfig = { pageAds: true, playerAds: true, xPlatform: true };
#   </script>
#   <script async="" data-nscript="beforeInteractive" id="inline-googletag">
#    window.googletag = window.googletag || { cmd: [] };
#   </script>
#   <link as="style" href="/bbcx/_next/static/css/d33e6c14cf3d6d34.css" rel="preload"/>
#   <link data-n-g="" href="/bbcx/_next/static/css/d33e6c14cf3d6d34.css" rel="stylesheet"/>
#   <noscript data-n-css="">
#   </noscript>
#   <script defer="" nomodule="" src="/bbcx/_next/static/chunks/polyfills-c67a75d1b6f99dc8.js">
#   </script>
#   <script async="" data-nscript="beforeInteractive" defer="" id="requirejs-script" src="https://static.bbci.co.uk/frameworks/requirejs/0.13.0/sharedmodules/require.js" type="text/javascript">
#   </script>
#   <script async="" data-nscript="beforeInteractive" defer="" id="ads-service-script" src="https://gn-web-assets.api.bbc.com/ngas/latest/dotcom-bootstrap.js" type="module">
#   </script>
#   <script async="" data-nscript="beforeInteractive" defer="" id="inline-block-ads" src="/blockAdBlock.js">
#   </script>
#   <script async="" data-nscript="beforeInteractive" defer="" id="inline-prebid-ads" src="/prebid-ads.js">
#   </script>
#   <script async="" data-nscript="beforeInteractive" defer="" id="bump-script" src="https://emp.bbci.co.uk/emp/bump-4/bump-4.js" type="text/javascript">
#   </script>
#   <script defer="" src="/bbcx/_next/static/chunks/webpack-29bbea4c57b4d594.js">
#   </script>
#   <script defer="" src="/bbcx/_next/static/chunks/framework-3adfd9c6527e6ba9.js">
#   </script>
#   <script defer="" src="/bbcx/_next/static/chunks/main-2dc0acb15c3c6316.js">
#   </script>
#   <script defer="" src="/bbcx/_next/static/chunks/pages/_app-0923e07fe6e8dc7b.js">
#   </script>
#   <script defer="" src="/bbcx/_next/static/chunks/pages/%5B%5B...slug%5D%5D-c28223db78396f64.js">
#   </script>
#   <script defer="" src="/bbcx/_next/static/RW0_0zYhiq0qNDyC0vO0x/_buildManifest.js">
#   </script>
#   <script defer="" src="/bbcx/_next/static/RW0_0zYhiq0qNDyC0vO0x/_ssgManifest.js">
#   </script>
#   <style data-styled="" data-styled-version="5.3.11">
#    html,body,div,span,applet,object,iframe,h1,h2,h3,h4,h5,h6,p,blockquote,pre,a,abbr,acronym,address,big,cite,code,del,dfn,em,img,ins,kbd,q,s,samp,small,strike,strong,sub,sup,tt,var,b,u,i,center,dl,dt,dd,ol,ul,li,fieldset,form,label,legend,table,caption,tbody,tfoot,thead,tr,th,td,article,aside,canvas,details,embed,figure,figcaption,footer,header,hgroup,main,menu,nav,output,ruby,section,summary,time,mark,audio,video{margin:0;padding:0;border:0;font:inherit;vertical-align:baseline;}/*!sc*/
# article,aside,details,figcaption,figure,footer,header,hgroup,main,menu,nav,section{display:block;}/*!sc*/
# body{line-height:1;}/*!sc*/
# @supports (-webkit-text-size-adjust:none) or (text-size-adjust:none){body{-webkit-text-size-adjust:none;text-size-adjust:none;}}/*!sc*/
# ol,ul{list-style:none;}/*!sc*/
# blockquote,q{quotes:none;}/*!sc*/
# blockquote::before,blockquote::after,q::before,q::after{content:'';}/*!sc*/
# table{border-collapse:collapse;border-spacing:0;}/*!sc*/
# button{-webkit-appearance:none;-moz-appearance:none;appearance:none;margin:0;padding:0;background:none;border-radius:0;border:0;font-family:inherit;color:inherit;}/*!sc*/
# data-styled.g1[id="sc-global-igImlZ1"]{content:"sc-global-igImlZ1,"}/*!sc*/
# .gXZDla{box-sizing:border-box;display:grid;gap:16px;margin:0 auto;width:1248px;}/*!sc*/
# @media screen and (max-width:1279px){.gXZDla{margin:0 16px;width:auto;}}/*!sc*/
# @media screen and (max-width:767px){.gXZDla{margin:0 16px;width:auto;}}/*!sc*/
# @media screen and (max-width:599px){.gXZDla{margin:0;width:auto;}}/*!sc*/
# @media screen and (max-width:8192px){}/*!sc*/
# @media screen and (max-width:1279px){}/*!sc*/
# @media screen and (max-width:1007px){}/*!sc*/
# @media screen and (max-width:767px){}/*!sc*/
# @media screen and (max-width:599px){}/*!sc*/
# @media screen and (max-width:399px){}/*!sc*/
# data-styled.g3[id="sc-4e574cd-0"]{content:"gXZDla,"}/*!sc*/
# .dckLVJ{display:grid;box-sizing:border-box;-webkit-align-items:start;-webkit-box-align:start;-ms-flex-align:start;align-items:start;}/*!sc*/
# @media screen and (max-width:8192px){.dckLVJ{grid-gap:16px;margin:0 0 8px 0;grid-row:1 / span 1;grid-column:1 / span 1;}}/*!sc*/
# @media screen and (max-width:1279px){.dckLVJ{grid-gap:16px;margin:0 0 8px 0;grid-row:1 / span 1;grid-column:1 / span 1;}}/*!sc*/
# @media screen and (max-width:1007px){.dckLVJ{grid-gap:16px;margin:0 0 16px 0;grid-row:1 / span 1;grid-column:1 / span 1;}}/*!sc*/
# @media screen and (max-width:767px){.dckLVJ{grid-gap:16px;margin:0 0 16px 0;grid-row:1 / span 1;grid-column:1 / span 2;}}/*!sc*/
# @media screen and (max-width:599px){.dckLVJ{grid-gap:16px;margin:0 0 16px 0;grid-row:1 / span 1;grid-column:1 / span 2;}}/*!sc*/
# @media screen and (max-width:399px){.dckLVJ{grid-gap:16px;margin:0 0 16px 0;grid-row:1 / span 1;grid-column:1 / span 2;}}/*!sc*/
# .ckmhTf{display:grid;box-sizing:border-box;-webkit-align-items:start;-webkit-box-align:start;-ms-flex-align:start;align-items:start;}/*!sc*/
# @media screen and (max-width:8192px){.ckmhTf{grid-gap:16px;grid-row:1 / span 1;grid-column:2 / span 1;}}/*!sc*/
# @media screen and (max-width:1279px){.ckmhTf{grid-gap:16px;grid-row:1 / span 1;grid-column:2 / span 1;}}/*!sc*/
# @media screen and (max-width:1007px){.ckmhTf{grid-gap:16px;grid-row:1 / span 1;grid-column:2 / span 1;}}/*!sc*/
# @media screen and (max-width:767px){.ckmhTf{grid-gap:16px;grid-row:4 / span 1;grid-column:1 / span 2;}}/*!sc*/
# @media screen and (max-width:599px){.ckmhTf{grid-gap:16px;grid-row:4 / span 1;grid-column:1 / span 2;}}/*!sc*/
# @media screen and (max-width:399px){.ckmhTf{grid-gap:16px;grid-row:4 / span 1;grid-column:1 / span 2;}}/*!sc*/
# .dnpSXe{display:grid;box-sizing:border-box;-webkit-align-items:start;-webkit-box-align:start;-ms-flex-align:start;align-items:start;}/*!sc*/
# @media screen and (max-width:8192px){.dnpSXe{grid-gap:16px;grid-row:2 / span 2;grid-column:2 / span 1;}}/*!sc*/
# @media screen and (max-width:1279px){.dnpSXe{grid-gap:16px;grid-row:2 / span 2;grid-column:2 / span 1;}}/*!sc*/
# @media screen and (max-width:1007px){.dnpSXe{grid-gap:16px;grid-row:2 / span 2;grid-column:2 / span 1;}}/*!sc*/
# @media screen and (max-width:767px){.dnpSXe{grid-gap:16px;grid-row:5 / span 1;grid-column:1 / span 2;}}/*!sc*/
# @media screen and (max-width:599px){.dnpSXe{grid-gap:16px;grid-row:5 / span 1;grid-column:1 / span 2;}}/*!sc*/
# @media screen and (max-width:399px){.dnpSXe{grid-gap:16px;grid-row:5 / span 1;grid-column:1 / span 2;}}/*!sc*/
# .jOSbIh{display:grid;box-sizing:border-box;-webkit-align-items:start;-webkit-box-align:start;-ms-flex-align:start;align-items:start;}/*!sc*/
# @media screen and (max-width:8192px){.jOSbIh{grid-template-columns:repeat(3,1fr);grid-gap:16px;grid-row:2 / span 1;grid-column:1 / span 1;}}/*!sc*/
# @media screen and (max-width:1279px){.jOSbIh{grid-template-columns:repeat(3,1fr);grid-gap:16px;grid-row:2 / span 1;grid-column:1 / span 1;}}/*!sc*/
# @media screen and (max-width:1007px){.jOSbIh{grid-template-columns:repeat(2,1fr);grid-gap:16px;grid-row:2 / span 2;grid-column:1 / span 1;}}/*!sc*/
# @media screen and (max-width:767px){.jOSbIh{grid-template-columns:repeat(2,1fr);grid-gap:16px;grid-row:2 / span 2;grid-column:1 / span 2;}}/*!sc*/
# @media screen and (max-width:599px){.jOSbIh{grid-template-columns:repeat(1,1fr);grid-gap:16px;grid-row:2 / span 1;grid-column:1 / span 2;}}/*!sc*/
# @media screen and (max-width:399px){.jOSbIh{grid-template-columns:repeat(1,1fr);grid-gap:16px;grid-row:2 / span 1;grid-column:1 / span 2;}}/*!sc*/
# .fvGkoc{display:grid;box-sizing:border-box;}/*!sc*/
# @media screen and (max-width:8192px){.fvGkoc{grid-template-columns:repeat(5,1fr);grid-template-rows:auto;grid-gap:16px;margin:0 16px;}}/*!sc*/
# @media screen and (max-width:1279px){.fvGkoc{grid-template-columns:repeat(5,1fr);grid-template-rows:auto;grid-gap:16px;margin:0 16px;}}/*!sc*/
# @media screen and (max-width:1007px){.fvGkoc{grid-template-columns:repeat(3,1fr);grid-template-rows:auto;grid-gap:16px;margin:0 16px;}}/*!sc*/
# @media screen and (max-width:767px){.fvGkoc{grid-template-columns:repeat(2,1fr);grid-template-rows:auto;grid-gap:16px;margin:0 16px;}}/*!sc*/
# @media screen and (max-width:599px){.fvGkoc{grid-template-columns:repeat(1,1fr);grid-template-rows:auto;grid-gap:16px;margin:0 16px;}}/*!sc*/
# @media screen and (max-width:399px){.fvGkoc{grid-template-columns:repeat(1,1fr);grid-template-rows:auto;grid-gap:16px;margin:0 16px;}}/*!sc*/
# .dzHQkZ{display:grid;box-sizing:border-box;}/*!sc*/
# @media screen and (max-width:8192px){.dzHQkZ{grid-template-columns:repeat(1,1fr);grid-gap:24px;}}/*!sc*/
# @media screen and (max-width:1279px){.dzHQkZ{grid-template-columns:repeat(1,1fr);grid-gap:24px;}}/*!sc*/
# @media screen and (max-width:1007px){.dzHQkZ{grid-template-columns:repeat(1,1fr);grid-gap:24px;}}/*!sc*/
# @media screen and (max-width:767px){.dzHQkZ{grid-template-columns:repeat(1,1fr);grid-gap:24px;}}/*!sc*/
# @media screen and (max-width:599px){.dzHQkZ{grid-template-columns:repeat(1,1fr);grid-gap:16px;}}/*!sc*/
# @media screen and (max-width:399px){.dzHQkZ{grid-template-columns:repeat(1,1fr);grid-gap:16px;}}/*!sc*/
# data-styled.g4[id="sc-5b94fa74-0"]{content:"dckLVJ,ckmhTf,dnpSXe,jOSbIh,fvGkoc,dzHQkZ,"}/*!sc*/
# .gzOvMy{-webkit-text-decoration:none;text-decoration:none;cursor:pointer;color:unset;}/*!sc*/
# data-styled.g6[id="sc-4befc967-1"]{content:"gzOvMy,"}/*!sc*/
# .jQYtVJ{position:relative;line-height:0;}/*!sc*/
# data-styled.g8[id="sc-72a8a9a8-0"]{content:"jQYtVJ,"}/*!sc*/
# .cVIWlY{width:100%;object-fit:contain;background:url(https://ichef.bbci.co.uk/images/ic/raw/p0fxw69t.png) no-repeat;background-size:contain;}/*!sc*/
# data-styled.g10[id="sc-8d5354b4-0"]{content:"cVIWlY,"}/*!sc*/
# .kUFdej{-webkit-text-decoration:underline;text-decoration:underline;color:#202224;font-family:'__reithSerif_3e9265', Helvetica,Arial,sans-serif;font-weight:500;font-size:18px;line-height:26px;text-transform:none;-webkit-text-decoration:underline;text-decoration:underline;-webkit-letter-spacing:-0.36px;-moz-letter-spacing:-0.36px;-ms-letter-spacing:-0.36px;letter-spacing:-0.36px;}/*!sc*/
# @media screen and (max-width:399px){.kUFdej{font-family:'__reithSerif_3e9265', Helvetica,Arial,sans-serif;font-weight:500;font-size:16px;line-height:24px;text-transform:none;-webkit-text-decoration:underline;text-decoration:underline;-webkit-letter-spacing:-0.32px;-moz-letter-spacing:-0.32px;-ms-letter-spacing:-0.32px;letter-spacing:-0.32px;}}/*!sc*/
# @media screen and (max-width:599px){.kUFdej{font-family:'__reithSerif_3e9265', Helvetica,Arial,sans-serif;font-weight:500;font-size:16px;line-height:24px;text-transform:none;-webkit-text-decoration:underline;text-decoration:underline;-webkit-letter-spacing:-0.32px;-moz-letter-spacing:-0.32px;-ms-letter-spacing:-0.32px;letter-spacing:-0.32px;}}/*!sc*/
# data-styled.g11[id="sc-c9299ecf-0"]{content:"kUFdej,"}/*!sc*/
# .gDEGTg{color:#202224;font-family:'__reithSerif_3e9265', Helvetica,Arial,sans-serif;font-weight:400;font-size:18px;line-height:26px;text-transform:none;-webkit-text-decoration:none;text-decoration:none;-webkit-letter-spacing:-0.36px;-moz-letter-spacing:-0.36px;-ms-letter-spacing:-0.36px;letter-spacing:-0.36px;}/*!sc*/
# @media screen and (max-width:399px){.gDEGTg{font-family:'__reithSerif_3e9265', Helvetica,Arial,sans-serif;font-weight:400;font-size:16px;line-height:24px;text-transform:none;-webkit-text-decoration:none;text-decoration:none;-webkit-letter-spacing:-0.32px;-moz-letter-spacing:-0.32px;-ms-letter-spacing:-0.32px;letter-spacing:-0.32px;}}/*!sc*/
# @media screen and (max-width:599px){.gDEGTg{font-family:'__reithSerif_3e9265', Helvetica,Arial,sans-serif;font-weight:400;font-size:16px;line-height:24px;text-transform:none;-webkit-text-decoration:none;text-decoration:none;-webkit-letter-spacing:-0.32px;-moz-letter-spacing:-0.32px;-ms-letter-spacing:-0.32px;letter-spacing:-0.32px;}}/*!sc*/
# data-styled.g13[id="sc-eb7bd5f6-0"]{content:"gDEGTg,"}/*!sc*/
# .kKcaog{font-style:italic;}/*!sc*/
# @media screen and (max-width:599px){.kKcaog{word-break:break-word;}}/*!sc*/
# .kVRnKf{font-weight:600;}/*!sc*/
# @media screen and (max-width:599px){.kVRnKf{word-break:break-word;}}/*!sc*/
# data-styled.g16[id="sc-7dcfb11b-0"]{content:"kKcaog,kVRnKf,"}/*!sc*/
# .kBCmpn{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# .kBCmpn svg{width:100%;height:100%;}/*!sc*/
# data-styled.g18[id="sc-e41ce09d-0"]{content:"kBCmpn,"}/*!sc*/
# .eswlvd{cursor:pointer;font-weight:500;padding:6px 12px 6px 12px;border:2px solid transparent;outline:2px solid transparent;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;-webkit-column-gap:9.3px;column-gap:9.3px;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;box-sizing:border-box;font-family:'__reithSans_aa0e4a', Helvetica,Arial,sans-serif;font-weight:500;font-size:16px;line-height:18px;text-transform:none;-webkit-text-decoration:none;text-decoration:none;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;}/*!sc*/
# data-styled.g20[id="sc-e41ce09d-2"]{content:"eswlvd,"}/*!sc*/
# .jmLRHZ{background-color:#000000;color:#ffffff;border-color:#000000;outline-color:#000000;}/*!sc*/
# .jmLRHZ:hover{background-color:#3a3c3e;border-color:#3a3c3e;outline-color:#3a3c3e;}/*!sc*/
# .jmLRHZ:focus{outline:2px solid #000000;border:2px solid #ffffff;}/*!sc*/
# .jmLRHZ:active{background-color:#000000;color:#ffffff;border-color:#000000;outline-color:#000000;}/*!sc*/
# .jmLRHZ:disabled,.jmLRHZ[disabled]{cursor:not-allowed;background-color:#d2d4d6;color:#8a8c8e;outline-color:#d2d4d6;border-color:#d2d4d6;}/*!sc*/
# data-styled.g21[id="sc-e41ce09d-3"]{content:"jmLRHZ,"}/*!sc*/
# .iHqyyW{border-bottom:1px solid #e6e8ea;-webkit-transition:opacity 0.2s ease-in-out;transition:opacity 0.2s ease-in-out;grid-auto-rows:auto auto 1fr auto;position:relative;display:grid;opacity:1;}/*!sc*/
# .iHqyyW:hover img{opacity:0.8;}/*!sc*/
# .iHqyyW:hover h3{-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# data-styled.g48[id="sc-2c2f2429-0"]{content:"iHqyyW,"}/*!sc*/
# .cBPOQE{position:relative;}/*!sc*/
# data-styled.g49[id="sc-2c2f2429-1"]{content:"cBPOQE,"}/*!sc*/
# .zMPQE{height:100%;width:100%;}/*!sc*/
# .zMPQE img{aspect-ratio:16 / 9;object-fit:cover;}/*!sc*/
# data-styled.g50[id="sc-2c2f2429-2"]{content:"zMPQE,"}/*!sc*/
# .bmuaxk{background-color:#ffffff;color:#ffffff;grid-gap:12px;display:grid;padding-top:8px;}/*!sc*/
# data-styled.g51[id="sc-2c2f2429-3"]{content:"bmuaxk,"}/*!sc*/
# .loBKGz{color:#202224;font-family:'__reithSerif_3e9265', Helvetica,Arial,sans-serif;font-weight:400;font-size:14px;line-height:18px;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;}/*!sc*/
# @media screen and (max-width:599px){.loBKGz{font-family:'__reithSerif_3e9265', Helvetica,Arial,sans-serif;font-weight:400;font-size:14px;line-height:18px;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;}}/*!sc*/
# data-styled.g52[id="sc-2c2f2429-4"]{content:"loBKGz,"}/*!sc*/
# .bhsGjX{font-family:'__reithSerif_3e9265', Helvetica,Arial,sans-serif;font-weight:400;font-size:14px;line-height:18px;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;color:#202224;margin-bottom:56px;}/*!sc*/
# @media screen and (max-width:599px){.bhsGjX{font-family:'__reithSerif_3e9265', Helvetica,Arial,sans-serif;font-weight:400;font-size:14px;line-height:18px;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;margin-bottom:48px;}}/*!sc*/
# data-styled.g66[id="sc-cee500c-0"]{content:"bhsGjX,"}/*!sc*/
# .jnuLQH{-webkit-align-items:start;-webkit-box-align:start;-ms-flex-align:start;align-items:start;display:grid;}/*!sc*/
# data-styled.g67[id="sc-cee500c-1"]{content:"jnuLQH,"}/*!sc*/
# .kjKWeB{height:100%;width:100%;}/*!sc*/
# .kjKWeB img{aspect-ratio:16 / 9;object-fit:cover;}/*!sc*/
# data-styled.g68[id="sc-cee500c-2"]{content:"kjKWeB,"}/*!sc*/
# .gFetrx{border-bottom:1px solid #e6e8ea;position:relative;min-height:190px;display:block;}/*!sc*/
# .jYkDce{border-bottom:none;position:relative;min-height:190px;display:block;}/*!sc*/
# data-styled.g69[id="sc-cee500c-3"]{content:"gFetrx,jYkDce,"}/*!sc*/
# .iYWEjl{grid-template-columns:90px 1fr;-webkit-align-items:stretch;-webkit-box-align:stretch;-ms-flex-align:stretch;align-items:stretch;position:relative;display:grid;gap:16px;}/*!sc*/
# .iYWEjl:hover img{opacity:0.8;}/*!sc*/
# .iYWEjl:hover h3{-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# @media screen and (max-width:599px){.iYWEjl{grid-template-columns:1fr;}}/*!sc*/
# data-styled.g70[id="sc-cee500c-4"]{content:"iYWEjl,"}/*!sc*/
# .fTtgb{margin-bottom:16px;position:relative;margin-left:16px;float:right;width:300px;}/*!sc*/
# @media screen and (max-width:599px){.fTtgb{margin-bottom:8px;margin-left:8px;width:50%;}}/*!sc*/
# data-styled.g71[id="sc-cee500c-5"]{content:"fTtgb,"}/*!sc*/
# .eNHMic{display:block;}/*!sc*/
# data-styled.g72[id="sc-cee500c-6"]{content:"eNHMic,"}/*!sc*/
# .fsjsPV{font-family:'__reithSerif_3e9265', Helvetica,Arial,sans-serif;font-weight:400;font-size:14px;line-height:18px;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;color:#202224;margin-bottom:4px;}/*!sc*/
# @media screen and (max-width:599px){.fsjsPV{font-family:'__reithSerif_3e9265', Helvetica,Arial,sans-serif;font-weight:400;font-size:14px;line-height:18px;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;margin-bottom:0;}}/*!sc*/
# data-styled.g73[id="sc-bcf5c03b-0"]{content:"fsjsPV,"}/*!sc*/
# .sjbHr{height:100%;width:100%;}/*!sc*/
# .sjbHr img{aspect-ratio:16 / 9;object-fit:cover;}/*!sc*/
# @media screen and (max-width:599px){.sjbHr{width:calc(100% + 32px);margin-right:-16px;margin-left:-16px;}}/*!sc*/
# data-styled.g74[id="sc-bcf5c03b-1"]{content:"sjbHr,"}/*!sc*/
# .bNrFQe{grid-template-columns:1fr 2fr;border-bottom:1px solid #e6e8ea;background-color:transparent;position:relative;padding:0;margin:0;grid-gap:16px;display:grid;}/*!sc*/
# .bNrFQe:hover img{opacity:0.8;}/*!sc*/
# .bNrFQe:hover h3{-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# @media screen and (max-width:1007px){.bNrFQe{grid-template-columns:1fr 3fr;grid-gap:12px;}}/*!sc*/
# @media screen and (max-width:767px){.bNrFQe{grid-template-columns:1fr;}}/*!sc*/
# @media screen and (max-width:599px){.bNrFQe{margin:0 -16px;padding:0 16px;}}/*!sc*/
# data-styled.g75[id="sc-bcf5c03b-2"]{content:"bNrFQe,"}/*!sc*/
# .fBQoMP{background-color:transparent;-webkit-align-items:stretch;-webkit-box-align:stretch;-ms-flex-align:stretch;align-items:stretch;position:relative;display:grid;grid-gap:0;}/*!sc*/
# @media screen and (max-width:1007px){.fBQoMP{grid-gap:16px;}}/*!sc*/
# @media screen and (max-width:599px){.fBQoMP{grid-gap:0;}}/*!sc*/
# data-styled.g76[id="sc-bcf5c03b-3"]{content:"fBQoMP,"}/*!sc*/
# .dTzowl{position:relative;-webkit-align-self:start;-ms-flex-item-align:start;align-self:start;-webkit-order:2;-ms-flex-order:2;order:2;}/*!sc*/
# @media screen and (max-width:767px){.dTzowl{-webkit-order:unset;-ms-flex-order:unset;order:unset;}}/*!sc*/
# data-styled.g77[id="sc-bcf5c03b-4"]{content:"dTzowl,"}/*!sc*/
# .lobrFA{-webkit-order:1;-ms-flex-order:1;order:1;grid-gap:12px;display:grid;-webkit-align-content:start;-ms-flex-line-pack:start;align-content:start;-webkit-align-items:start;-webkit-box-align:start;-ms-flex-align:start;align-items:start;}/*!sc*/
# data-styled.g78[id="sc-bcf5c03b-5"]{content:"lobrFA,"}/*!sc*/
# .bWGEXP{display:grid;grid-gap:12px;}/*!sc*/
# .bWGEXP > *:nth-child(2){border-top:1px solid #e6e8ea;padding-top:12px;}/*!sc*/
# data-styled.g79[id="sc-bcf5c03b-6"]{content:"bWGEXP,"}/*!sc*/
# .bNzKIA{font-family:'__reithSerif_3e9265', Helvetica,Arial,sans-serif;font-weight:400;font-size:14px;line-height:18px;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;color:#202224;margin-bottom:4px;}/*!sc*/
# @media screen and (max-width:599px){.bNzKIA{font-family:'__reithSerif_3e9265', Helvetica,Arial,sans-serif;font-weight:400;font-size:14px;line-height:18px;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;margin-bottom:0;}}/*!sc*/
# data-styled.g80[id="sc-6d72d12a-0"]{content:"bNzKIA,"}/*!sc*/
# .gmzJUh{border-bottom:1px solid #e6e8ea;position:relative;grid-gap:8px;display:grid;}/*!sc*/
# .gmzJUh:hover h3{-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# data-styled.g81[id="sc-6d72d12a-1"]{content:"gmzJUh,"}/*!sc*/
# .gnuanj{position:relative;grid-gap:8px;display:grid;}/*!sc*/
# data-styled.g82[id="sc-6d72d12a-2"]{content:"gnuanj,"}/*!sc*/
# .hYxbtM{margin-top:29px;}/*!sc*/
# @media screen and (max-width:399px){.hYxbtM{margin-top:24px;}}/*!sc*/
# @media screen and (max-width:599px){.hYxbtM{margin-top:24px;}}/*!sc*/
# data-styled.g119[id="sc-19b1eb93-0"]{content:"hYxbtM,"}/*!sc*/
# .fwyFkM{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;-webkit-column-gap:16px;column-gap:16px;row-gap:18px;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;}/*!sc*/
# @media screen and (max-width:399px){.fwyFkM{-webkit-align-items:flex-start;-webkit-box-align:flex-start;-ms-flex-align:flex-start;align-items:flex-start;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;row-gap:24px;-webkit-column-gap:0;column-gap:0;}}/*!sc*/
# @media screen and (max-width:599px){.fwyFkM{-webkit-align-items:flex-start;-webkit-box-align:flex-start;-ms-flex-align:flex-start;align-items:flex-start;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;row-gap:24px;-webkit-column-gap:0;column-gap:0;}}/*!sc*/
# data-styled.g120[id="sc-19b1eb93-1"]{content:"fwyFkM,"}/*!sc*/
# .kWeMlj{-webkit-text-decoration:none;text-decoration:none;position:relative;color:#000000;font-family:'__reithSans_aa0e4a', Helvetica,Arial,sans-serif;font-weight:500;font-size:14px;line-height:18px;text-transform:none;-webkit-text-decoration:none;text-decoration:none;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;}/*!sc*/
# .kWeMlj:hover{-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# data-styled.g121[id="sc-19b1eb93-2"]{content:"kWeMlj,"}/*!sc*/
# .bDkVIF{background-color:#00000033;display:none;top:0px;position:fixed;border:none;width:100%;bottom:0;z-index:3000;}/*!sc*/
# .bDkVIF *{z-index:3000;}/*!sc*/
# data-styled.g128[id="sc-d2d98e04-0"]{content:"bDkVIF,"}/*!sc*/
# .hgisAf{position:fixed;display:block;bottom:0;width:100%;background-color:#ffffff;z-index:3000;-webkit-transition:-webkit-transform 0.1s ease-in-out;-webkit-transition:transform 0.1s ease-in-out;transition:transform 0.1s ease-in-out;top:0px;left:0;width:320px;-webkit-transform:translateX(-100%);-ms-transform:translateX(-100%);transform:translateX(-100%);}/*!sc*/
# .hgisAf *{z-index:3000;}/*!sc*/
# @media screen and (max-width:599px){.hgisAf{width:100%;}}/*!sc*/
# data-styled.g129[id="sc-d2d98e04-1"]{content:"hgisAf,"}/*!sc*/
# .dzCnly{max-width:1280px;margin:16px auto 48px auto;padding-left:16px;}/*!sc*/
# data-styled.g130[id="sc-ba224a1-0"]{content:"dzCnly,"}/*!sc*/
# .cMQOuo{margin-top:16px;}/*!sc*/
# .cMQOuo p{font-family:'__reithSans_aa0e4a', Helvetica,Arial,sans-serif;font-weight:400;font-size:12px;line-height:16px;text-transform:none;-webkit-text-decoration:none;text-decoration:none;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;}/*!sc*/
# .cMQOuo b,.cMQOuo a{font-family:'__reithSans_aa0e4a', Helvetica,Arial,sans-serif;font-weight:700;font-size:12px;line-height:16px;text-transform:none;-webkit-text-decoration:none;text-decoration:none;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;}/*!sc*/
# .cMQOuo a{-webkit-text-decoration:none;text-decoration:none;color:#000000;}/*!sc*/
# @media screen and (max-width:599px){.cMQOuo{margin-top:24px;}}/*!sc*/
# data-styled.g131[id="sc-ba224a1-1"]{content:"cMQOuo,"}/*!sc*/
# .boQOzm{background-color:#3a3c3e;margin-top:16px;height:1px;border:none;}/*!sc*/
# .yUcMM{background-color:#e6e8ea;margin-top:16px;height:1px;border:none;}/*!sc*/
# data-styled.g132[id="sc-ba224a1-2"]{content:"boQOzm,yUcMM,"}/*!sc*/
# @media screen and (max-width:1279px){.fTBhwF{display:none;}}/*!sc*/
# data-styled.g133[id="sc-ba224a1-3"]{content:"fTBhwF,"}/*!sc*/
# .mcmMa{margin-top:0px;height:32px;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;gap:8px;}/*!sc*/
# @media screen and (max-width:399px){.mcmMa{margin-top:0px;}}/*!sc*/
# @media screen and (max-width:599px){.mcmMa{margin-top:0px;}}/*!sc*/
# .bBUimm{margin-top:4px;height:32px;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;gap:8px;}/*!sc*/
# @media screen and (max-width:399px){.bBUimm{margin-top:4px;}}/*!sc*/
# @media screen and (max-width:599px){.bBUimm{margin-top:4px;}}/*!sc*/
# .dGeSbp{margin-top:0px;height:auto;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;gap:8px;}/*!sc*/
# @media screen and (max-width:399px){.dGeSbp{display:none;}}/*!sc*/
# @media screen and (max-width:599px){.dGeSbp{display:none;}}/*!sc*/
# @media screen and (max-width:399px){.dGeSbp{margin-top:2px;}}/*!sc*/
# @media screen and (max-width:599px){.dGeSbp{margin-top:2px;}}/*!sc*/
# .dIiwqJ{margin-top:0px;height:32px;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;gap:8px;position:absolute;bottom:0;}/*!sc*/
# @media screen and (max-width:399px){.dIiwqJ{margin-top:2px;}}/*!sc*/
# @media screen and (max-width:599px){.dIiwqJ{margin-top:2px;}}/*!sc*/
# data-styled.g135[id="sc-ec7fe2bd-0"]{content:"mcmMa,bBUimm,dGeSbp,dIiwqJ,"}/*!sc*/
# .eIXzYS{font-family:'__reithSans_aa0e4a', Helvetica,Arial,sans-serif;font-weight:400;font-size:12px;line-height:14px;text-transform:none;-webkit-text-decoration:none;text-decoration:none;-webkit-letter-spacing:-0.12px;-moz-letter-spacing:-0.12px;-ms-letter-spacing:-0.12px;letter-spacing:-0.12px;color:#545658;}/*!sc*/
# .VpUCh{font-family:'__reithSans_aa0e4a', Helvetica,Arial,sans-serif;font-weight:400;font-size:12px;line-height:14px;text-transform:none;-webkit-text-decoration:none;text-decoration:none;-webkit-letter-spacing:-0.12px;-moz-letter-spacing:-0.12px;-ms-letter-spacing:-0.12px;letter-spacing:-0.12px;color:#545658;}/*!sc*/
# @media screen and (max-width:767px){.VpUCh{display:block;}}/*!sc*/
# @media screen and (max-width:1007px){.VpUCh{display:block;}}/*!sc*/
# @media screen and (max-width:1279px){.VpUCh{display:block;}}/*!sc*/
# @media screen and (max-width:8192px){.VpUCh{display:block;}}/*!sc*/
# @media screen and (max-width:399px){.VpUCh{display:none;}}/*!sc*/
# @media screen and (max-width:599px){.VpUCh{display:none;}}/*!sc*/
# .iNkFqh{font-family:'__reithSans_aa0e4a', Helvetica,Arial,sans-serif;font-weight:400;font-size:12px;line-height:14px;text-transform:none;-webkit-text-decoration:none;text-decoration:none;-webkit-letter-spacing:-0.12px;-moz-letter-spacing:-0.12px;-ms-letter-spacing:-0.12px;letter-spacing:-0.12px;color:#545658;}/*!sc*/
# @media screen and (max-width:767px){.iNkFqh{display:none;}}/*!sc*/
# @media screen and (max-width:1007px){.iNkFqh{display:none;}}/*!sc*/
# @media screen and (max-width:1279px){.iNkFqh{display:none;}}/*!sc*/
# @media screen and (max-width:8192px){.iNkFqh{display:none;}}/*!sc*/
# @media screen and (max-width:399px){.iNkFqh{display:block;}}/*!sc*/
# @media screen and (max-width:599px){.iNkFqh{display:block;}}/*!sc*/
# data-styled.g136[id="sc-ec7fe2bd-1"]{content:"eIXzYS,VpUCh,iNkFqh,"}/*!sc*/
# .grtqrQ{color:#545658;font-family:'__reithSans_aa0e4a', Helvetica,Arial,sans-serif;font-weight:400;font-size:12px;line-height:14px;text-transform:none;-webkit-text-decoration:none;text-decoration:none;-webkit-letter-spacing:-0.12px;-moz-letter-spacing:-0.12px;-ms-letter-spacing:-0.12px;letter-spacing:-0.12px;pointer-events:none;}/*!sc*/
# data-styled.g137[id="sc-ec7fe2bd-2"]{content:"grtqrQ,"}/*!sc*/
# .eyPbQc{background-color:#545658;margin:auto 2px;height:16px;width:1px;}/*!sc*/
# .eBlqFD{background-color:#545658;margin:auto 2px;height:16px;width:1px;}/*!sc*/
# @media screen and (max-width:767px){.eBlqFD{display:none;}}/*!sc*/
# @media screen and (max-width:1007px){.eBlqFD{display:none;}}/*!sc*/
# @media screen and (max-width:1279px){.eBlqFD{display:none;}}/*!sc*/
# @media screen and (max-width:8192px){.eBlqFD{display:none;}}/*!sc*/
# @media screen and (max-width:399px){.eBlqFD{display:block;}}/*!sc*/
# @media screen and (max-width:599px){.eBlqFD{display:block;}}/*!sc*/
# data-styled.g138[id="sc-ec7fe2bd-3"]{content:"eyPbQc,eBlqFD,"}/*!sc*/
# .cScezt{background-color:#ffffff;color:#000000;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;justify-items:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;position:absolute;min-width:24px;bottom:0;display:grid;left:0;}/*!sc*/
# @media screen and (max-width:599px){.cScezt{left:0px;display:grid;}}/*!sc*/
# data-styled.g140[id="sc-79ce7c57-0"]{content:"cScezt,"}/*!sc*/
# .jZbybi{-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;height:48px;width:48px;margin:8px;}/*!sc*/
# .jZbybi > svg{height:30px;}/*!sc*/
# @media screen and (max-width:599px){.jZbybi{height:32px;width:32px;margin:4px;}.jZbybi > svg{height:20px;}}/*!sc*/
# .buzvdL{-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;height:32px;width:32px;margin:4px;}/*!sc*/
# .buzvdL > svg{height:20px;}/*!sc*/
# @media screen and (max-width:599px){.buzvdL{height:32px;width:32px;margin:4px;}.buzvdL > svg{height:20px;}}/*!sc*/
# data-styled.g141[id="sc-79ce7c57-1"]{content:"jZbybi,buzvdL,"}/*!sc*/
# .gQGuCj{width:100%;margin-right:0;}/*!sc*/
# @media screen and (max-width:599px){.gQGuCj{margin-right:8px;}}/*!sc*/
# data-styled.g143[id="sc-70eaf3a9-0"]{content:"gQGuCj,"}/*!sc*/
# .cbEjyd{width:100%;}/*!sc*/
# @media screen and (max-width:599px){.cbEjyd{min-height:32px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}}/*!sc*/
# data-styled.g144[id="sc-70eaf3a9-1"]{content:"cbEjyd,iaCYGD,"}/*!sc*/
# .dfMhPx{color:#202224;grid-template-columns:auto auto;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;position:relative;padding-left:2px;margin:0 6px 0 0;display:grid;height:auto;width:auto;color:#EB0000;float:left;grid-gap:2.6px;}/*!sc*/
# .dfMhPx > svg{height:26.7px;width:26.7px;}/*!sc*/
# @media screen and (max-width:599px){.dfMhPx{grid-gap:2.3px;}.dfMhPx > svg{height:23px;}}/*!sc*/
# .ebgyGw{color:#202224;grid-template-columns:auto auto;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;position:relative;padding-left:2px;margin:0 6px 0 0;display:grid;height:auto;width:auto;color:#EB0000;float:left;grid-gap:1.8px;}/*!sc*/
# .ebgyGw > svg{height:18.3px;width:18.3px;}/*!sc*/
# @media screen and (max-width:599px){.ebgyGw{grid-gap:1.8px;}.ebgyGw > svg{height:18px;}}/*!sc*/
# data-styled.g145[id="sc-70eaf3a9-2"]{content:"dfMhPx,ebgyGw,"}/*!sc*/
# .lkuFhf{color:#202224;font-family:'__reithSerif_3e9265', Helvetica,Arial,sans-serif;font-weight:500;font-size:28px;line-height:32px;text-transform:none;-webkit-text-decoration:none;text-decoration:none;-webkit-letter-spacing:-0.56px;-moz-letter-spacing:-0.56px;-ms-letter-spacing:-0.56px;letter-spacing:-0.56px;font-family:'__reithSerif_3e9265', Helvetica,Arial,sans-serif;font-weight:500;font-size:28px;line-height:32px;text-transform:none;-webkit-text-decoration:none;text-decoration:none;-webkit-letter-spacing:-0.56px;-moz-letter-spacing:-0.56px;-ms-letter-spacing:-0.56px;letter-spacing:-0.56px;}/*!sc*/
# @media screen and (max-width:599px){.lkuFhf{font-family:'__reithSerif_3e9265', Helvetica,Arial,sans-serif;font-weight:500;font-size:24px;line-height:28px;text-transform:none;-webkit-text-decoration:none;text-decoration:none;-webkit-letter-spacing:-0.48px;-moz-letter-spacing:-0.48px;-ms-letter-spacing:-0.48px;letter-spacing:-0.48px;}}/*!sc*/
# @media screen and (max-width:599px){.lkuFhf{font-family:'__reithSerif_3e9265', Helvetica,Arial,sans-serif;font-weight:500;font-size:24px;line-height:28px;text-transform:none;-webkit-text-decoration:none;text-decoration:none;-webkit-letter-spacing:-0.48px;-moz-letter-spacing:-0.48px;-ms-letter-spacing:-0.48px;letter-spacing:-0.48px;}}/*!sc*/
# .jwHQEU{color:#202224;font-family:'__reithSerif_3e9265', Helvetica,Arial,sans-serif;font-weight:500;font-size:18px;line-height:22px;text-transform:none;-webkit-text-decoration:none;text-decoration:none;-webkit-letter-spacing:-0.36px;-moz-letter-spacing:-0.36px;-ms-letter-spacing:-0.36px;letter-spacing:-0.36px;}/*!sc*/
# @media screen and (max-width:599px){.jwHQEU{font-family:'__reithSerif_3e9265', Helvetica,Arial,sans-serif;font-weight:500;font-size:18px;line-height:22px;text-transform:none;-webkit-text-decoration:none;text-decoration:none;-webkit-letter-spacing:-0.36px;-moz-letter-spacing:-0.36px;-ms-letter-spacing:-0.36px;letter-spacing:-0.36px;}}/*!sc*/
# .hoFMJk{color:#202224;font-family:'__reithSerif_3e9265', Helvetica,Arial,sans-serif;font-weight:500;font-size:24px;line-height:28px;text-transform:none;-webkit-text-decoration:none;text-decoration:none;-webkit-letter-spacing:-0.48px;-moz-letter-spacing:-0.48px;-ms-letter-spacing:-0.48px;letter-spacing:-0.48px;margin-bottom:12px;font-family:'__reithSerif_3e9265', Helvetica,Arial,sans-serif;font-weight:500;font-size:24px;line-height:28px;text-transform:none;-webkit-text-decoration:none;text-decoration:none;-webkit-letter-spacing:-0.48px;-moz-letter-spacing:-0.48px;-ms-letter-spacing:-0.48px;letter-spacing:-0.48px;}/*!sc*/
# @media screen and (max-width:599px){.hoFMJk{font-family:'__reithSerif_3e9265', Helvetica,Arial,sans-serif;font-weight:500;font-size:20px;line-height:24px;text-transform:none;-webkit-text-decoration:none;text-decoration:none;-webkit-letter-spacing:-0.4px;-moz-letter-spacing:-0.4px;-ms-letter-spacing:-0.4px;letter-spacing:-0.4px;}}/*!sc*/
# @media screen and (max-width:599px){.hoFMJk{margin-bottom:8px;font-family:'__reithSerif_3e9265', Helvetica,Arial,sans-serif;font-weight:500;font-size:18px;line-height:22px;text-transform:none;-webkit-text-decoration:none;text-decoration:none;-webkit-letter-spacing:-0.36px;-moz-letter-spacing:-0.36px;-ms-letter-spacing:-0.36px;letter-spacing:-0.36px;}}/*!sc*/
# data-styled.g146[id="sc-70eaf3a9-3"]{content:"lkuFhf,jwHQEU,hoFMJk,"}/*!sc*/
# .egJcep{color:#202224;font-family:'__reithSans_aa0e4a', Helvetica,Arial,sans-serif;font-weight:700;font-size:28px;line-height:32px;text-transform:uppercase;-webkit-text-decoration:none;text-decoration:none;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;color:#EB0000;-webkit-text-decoration:none !important;text-decoration:none !important;text-transform:uppercase;}/*!sc*/
# @media screen and (max-width:599px){.egJcep{font-family:'__reithSans_aa0e4a', Helvetica,Arial,sans-serif;font-weight:700;font-size:24px;line-height:28px;text-transform:uppercase;-webkit-text-decoration:none;text-decoration:none;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;}}/*!sc*/
# .gIzBYa{color:#202224;font-family:'__reithSans_aa0e4a', Helvetica,Arial,sans-serif;font-weight:700;font-size:18px;line-height:22px;text-transform:uppercase;-webkit-text-decoration:none;text-decoration:none;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;color:#EB0000;-webkit-text-decoration:none !important;text-decoration:none !important;text-transform:uppercase;}/*!sc*/
# @media screen and (max-width:599px){.gIzBYa{font-family:'__reithSans_aa0e4a', Helvetica,Arial,sans-serif;font-weight:700;font-size:18px;line-height:22px;text-transform:uppercase;-webkit-text-decoration:none;text-decoration:none;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;}}/*!sc*/
# data-styled.g147[id="sc-70eaf3a9-4"]{content:"egJcep,gIzBYa,"}/*!sc*/
# .kzVmVM{display:grid;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# .kzVmVM > *{border-top:1px solid #e6e8ea;padding-bottom:12px;padding-right:8px;padding-top:12px;}/*!sc*/
# @media screen and (max-width:767px){.kzVmVM{display:none;}}/*!sc*/
# @media screen and (max-width:1007px){.kzVmVM{display:none;}}/*!sc*/
# @media screen and (max-width:599px){.kzVmVM{display:grid;}}/*!sc*/
# .hZOonD{display:grid;background-color:transparent;grid-template-columns:repeat(2,1fr);justify-items:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;display:none;}/*!sc*/
# .hZOonD > *{border-right:1px solid #e6e8ea;padding-right:8px;padding-left:16px;}/*!sc*/
# .hZOonD :last-child{border-right:none;}/*!sc*/
# .hZOonD :first-child{padding-left:0;}/*!sc*/
# @media screen and (max-width:1007px){.hZOonD{display:grid;}}/*!sc*/
# @media screen and (max-width:599px){.hZOonD{display:none;}}/*!sc*/
# data-styled.g149[id="sc-46b3209b-0"]{content:"kzVmVM,hZOonD,"}/*!sc*/
# .hzafvj{color:#202224;font-family:'__reithSerif_3e9265', Helvetica,Arial,sans-serif;font-weight:500;font-size:16px;line-height:20px;text-transform:none;-webkit-text-decoration:none;text-decoration:none;-webkit-letter-spacing:-0.32px;-moz-letter-spacing:-0.32px;-ms-letter-spacing:-0.32px;letter-spacing:-0.32px;}/*!sc*/
# .hzafvj:hover{-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# @media screen and (max-width:599px){.hzafvj{font-family:'__reithSerif_3e9265', Helvetica,Arial,sans-serif;font-weight:500;font-size:16px;line-height:20px;text-transform:none;-webkit-text-decoration:none;text-decoration:none;-webkit-letter-spacing:-0.32px;-moz-letter-spacing:-0.32px;-ms-letter-spacing:-0.32px;letter-spacing:-0.32px;}}/*!sc*/
# data-styled.g150[id="sc-46b3209b-1"]{content:"hzafvj,"}/*!sc*/
# .khWlJB{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;gap:5px;}/*!sc*/
# data-styled.g151[id="sc-46b3209b-2"]{content:"khWlJB,"}/*!sc*/
# .heLzKj{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;width:20px;height:20px;}/*!sc*/
# .heLzKj > svg{height:6px;width:6px;}/*!sc*/
# data-styled.g152[id="sc-46b3209b-3"]{content:"heLzKj,"}/*!sc*/
# .iOkyKB{display:grid;width:100%;padding-bottom:48px;}/*!sc*/
# .iOkyKB:first-of-type{padding-top:24px;}/*!sc*/
# .iOkyKB:last-of-type{padding-bottom:0;}/*!sc*/
# .iOkyKB:first-of-type hr{display:none;}/*!sc*/
# @media screen and (max-width:599px){.iOkyKB{padding-bottom:40px;}}/*!sc*/
# .bPDMPD{display:grid;width:100%;padding-bottom:48px;}/*!sc*/
# .bPDMPD:first-of-type{padding-top:24px;}/*!sc*/
# .bPDMPD:last-of-type{padding-bottom:0;}/*!sc*/
# @media screen and (max-width:599px){.bPDMPD{padding-bottom:40px;}}/*!sc*/
# data-styled.g160[id="sc-86aa332-1"]{content:"iOkyKB,bPDMPD,"}/*!sc*/
# .hWJRZx{max-width:1280px;width:100%;}/*!sc*/
# @media screen and (max-width:8192px){.hWJRZx{margin:0 auto;}}/*!sc*/
# data-styled.g161[id="sc-86aa332-2"]{content:"hWJRZx,"}/*!sc*/
# .jvXgkQ{margin-top:21px;}/*!sc*/
# @media screen and (max-width:1007px){.jvXgkQ{margin-top:24px;}}/*!sc*/
# @media screen and (max-width:399px){.jvXgkQ{margin-top:40px;}}/*!sc*/
# @media screen and (max-width:599px){.jvXgkQ{margin-top:40px;}}/*!sc*/
# data-styled.g162[id="sc-fb2f8b48-0"]{content:"jvXgkQ,"}/*!sc*/
# .Cbpyy{position:relative;}/*!sc*/
# data-styled.g163[id="sc-fb2f8b48-1"]{content:"Cbpyy,"}/*!sc*/
# .enKanj{cursor:pointer;height:44px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;padding:6px 12px;background-color:#e6e8ea;color:#202224;font-family:'__reithSans_aa0e4a', Helvetica,Arial,sans-serif;font-weight:500;font-size:14px;line-height:18px;text-transform:none;-webkit-text-decoration:none;text-decoration:none;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;}/*!sc*/
# .enKanj:hover{background-color:#d2d4d6;}/*!sc*/
# .enKanj[disabled]{cursor:auto;color:#8a8c8e;background-color:#d2d4d6;}/*!sc*/
# .enKanj:active{background-color:#e6e8ea;}/*!sc*/
# data-styled.g164[id="sc-fb2f8b48-2"]{content:"enKanj,"}/*!sc*/
# .dhFqbG{width:24px;height:24px;margin-left:4.5px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;color:#000000;}/*!sc*/
# data-styled.g165[id="sc-fb2f8b48-3"]{content:"dhFqbG,"}/*!sc*/
# .ilVVvM{margin-top:16px;}/*!sc*/
# data-styled.g171[id="sc-db176339-0"]{content:"ilVVvM,"}/*!sc*/
# .iKZcGw{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;-webkit-column-gap:16px;column-gap:16px;row-gap:12px;}/*!sc*/
# data-styled.g172[id="sc-db176339-1"]{content:"iKZcGw,"}/*!sc*/
# ...
#        <div>
#         <button class="sc-f67e2d82-2 hqnDbU" data-testid="level1NavButton-/travel">
#          <span class="sc-f67e2d82-3 lhGSRJ" data-testid="level1NavText-/travel">
#           Travel
#          </span>
#          <div class="sc-f67e2d82-1 ougvF" data-testid="menuItem-ChevronIconWrapper-/travel">
#           <svg category="arrows" class="sc-200855d3-0 hTnynj" data-testid="menuItem-ChevronIcon-/travel" height="1em" icon="chevron-down" viewbox="0 0 32 32" width="1em">
#            <path d="M17.7 22.6.9 4.2v6.7L16 27.8 31.1 11V4.3L14.3 22.6h3.4zm0 0L.9 4.2v6.7L16 27.8 31.1 11V4.3L14.3 22.6h3.4z">
#            </path>
#           </svg>
#          </div>
#         </button>
#         <div class="sc-f67e2d82-4 dFtMiT" data-testid="level1NavContent-/travel">
#          <div class="sc-f67e2d82-5 fYjbNv" data-testid="navigationPanel-navItem-level2">
#           <div class="sc-4befc967-0 bUlrPj">
#            <a class="sc-4befc967-1 gzOvMy" data-testid="internal-link" href="/travel">
#             <button class="sc-f67e2d82-2 cPpMFZ" data-testid="level2NavButton-/travel/travel">
#              <span class="sc-f67e2d82-3 lhGSRJ" data-testid="level2NavText-/travel/travel">
#               Travel
#              </span>
#             </button>
#            </a>
#           </div>
#          </div>
#          <div class="sc-f67e2d82-5 fYjbNv" data-testid="navigationPanel-navItem-level2">
#           <div class="sc-4befc967-0 bUlrPj">
#            <a class="sc-4befc967-1 gzOvMy" data-testid="internal-link" href="/travel/destinations">
#             <button class="sc-f67e2d82-2 cPpMFZ" data-testid="level2NavButton-/travel/destinations">
#              <span class="sc-f67e2d82-3 lhGSRJ" data-testid="level2NavText-/travel/destinations">
#               Destinations
#              </span>
#             </button>
#            </a>
#           </div>
#          </div>
#          <div class="sc-f67e2d82-5 fYjbNv" data-testid="navigationPanel-navItem-level2">
#           <div class="sc-4befc967-0 bUlrPj">
#            <a class="sc-4befc967-1 gzOvMy" data-testid="internal-link" href="/travel/worlds-table">
#             <button class="sc-f67e2d82-2 cPpMFZ" data-testid="level2NavButton-/travel/worlds-table">
#              <span class="sc-f67e2d82-3 lhGSRJ" data-testid="level2NavText-/travel/worlds-table">
#               World’s Table
#              </span>
#             </button>
#            </a>
#           </div>
#          </div>
#          <div class="sc-f67e2d82-5 fYjbNv" data-testid="navigationPanel-navItem-level2">
#           <div class="sc-4befc967-0 bUlrPj">
#            <a class="sc-4befc967-1 gzOvMy" data-testid="internal-link" href="/travel/cultural-experiences">
#             <button class="sc-f67e2d82-2 cPpMFZ" data-testid="level2NavButton-/travel/cultural-experiences">
#              <span class="sc-f67e2d82-3 lhGSRJ" data-testid="level2NavText-/travel/cultural-experiences">
#               Culture &amp; Experiences
#              </span>
#             </button>
#            </a>
#           </div>
#          </div>
#          <div class="sc-f67e2d82-5 fYjbNv" data-testid="navigationPanel-navItem-level2">
#           <div class="sc-4befc967-0 bUlrPj">
#            <a class="sc-4befc967-1 gzOvMy" data-testid="internal-link" href="/travel/adventures">
#             <button class="sc-f67e2d82-2 cPpMFZ" data-testid="level2NavButton-/travel/adventures">
#              <span class="sc-f67e2d82-3 lhGSRJ" data-testid="level2NavText-/travel/adventures">
#               Adventures
#              </span>
#             </button>
#            </a>
#           </div>
#          </div>
#          <div class="sc-f67e2d82-5 fYjbNv" data-testid="navigationPanel-navItem-level2">
#           <div class="sc-4befc967-0 bUlrPj">
#            <a class="sc-4befc967-1 gzOvMy" data-testid="internal-link" href="/travel/specialist">
#             <button class="sc-f67e2d82-2 cPpMFZ" data-testid="level2NavButton-/travel/specialist">
#              <span class="sc-f67e2d82-3 lhGSRJ" data-testid="level2NavText-/travel/specialist">
#               The SpeciaList
#              </span>
#             </button>
#            </a>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="sc-f67e2d82-5 hpFPKZ" data-testid="navigationPanel-navItem-level1">
#        <div>
#         <button class="sc-f67e2d82-2 hqnDbU" data-testid="level1NavButton-/future-planet">
#          <span class="sc-f67e2d82-3 lhGSRJ" data-testid="level1NavText-/future-planet">
#           Earth
#          </span>
#          <div class="sc-f67e2d82-1 ougvF" data-testid="menuItem-ChevronIconWrapper-/future-planet">
#           <svg category="arrows" class="sc-200855d3-0 hTnynj" data-testid="menuItem-ChevronIcon-/future-planet" height="1em" icon="chevron-down" viewbox="0 0 32 32" width="1em">
#            <path d="M17.7 22.6.9 4.2v6.7L16 27.8 31.1 11V4.3L14.3 22.6h3.4zm0 0L.9 4.2v6.7L16 27.8 31.1 11V4.3L14.3 22.6h3.4z">
#            </path>
#           </svg>
#          </div>
#         </button>
#         <div class="sc-f67e2d82-4 dFtMiT" data-testid="level1NavContent-/future-planet">
#          <div class="sc-f67e2d82-5 fYjbNv" data-testid="navigationPanel-navItem-level2">
#           <div class="sc-4befc967-0 bUlrPj">
#            <a class="sc-4befc967-1 gzOvMy" data-testid="internal-link" href="/future-planet">
#             <button class="sc-f67e2d82-2 cPpMFZ" data-testid="level2NavButton-/future-planet/future-planet">
#              <span class="sc-f67e2d82-3 lhGSRJ" data-testid="level2NavText-/future-planet/future-planet">
#               Earth
#              </span>
#             </button>
#            </a>
#           </div>
#          </div>
#          <div class="sc-f67e2d82-5 fYjbNv" data-testid="navigationPanel-navItem-level2">
#           <div class="sc-4befc967-0 bUlrPj">
#            <a class="sc-4befc967-1 gzOvMy" data-testid="internal-link" href="/future-planet/natural-wonders">
#             <button class="sc-f67e2d82-2 cPpMFZ" data-testid="level2NavButton-/future-planet/natural-wonders">
#              <span class="sc-f67e2d82-3 lhGSRJ" data-testid="level2NavText-/future-planet/natural-wonders">
#               Natural Wonders
#              </span>
#             </button>
#            </a>
#           </div>
#          </div>
#          <div class="sc-f67e2d82-5 fYjbNv" data-testid="navigationPanel-navItem-level2">
#           <div class="sc-4befc967-0 bUlrPj">
#            <a class="sc-4befc967-1 gzOvMy" data-testid="internal-link" href="/future-planet/weather-science">
#             <button class="sc-f67e2d82-2 cPpMFZ" data-testid="level2NavButton-/future-planet/weather-science">
#              <span class="sc-f67e2d82-3 lhGSRJ" data-testid="level2NavText-/future-planet/weather-science">
#               Weather &amp; Science
#              </span>
#             </button>
#            </a>
#           </div>
#          </div>
#          <div class="sc-f67e2d82-5 fYjbNv" data-testid="navigationPanel-navItem-level2">
#           <div class="sc-4befc967-0 bUlrPj">
#            <a class="sc-4befc967-1 gzOvMy" data-testid="internal-link" href="/future-planet/solutions">
#             <button class="sc-f67e2d82-2 cPpMFZ" data-testid="level2NavButton-/future-planet/solutions">
#              <span class="sc-f67e2d82-3 lhGSRJ" data-testid="level2NavText-/future-planet/solutions">
#               Climate Solutions
#              </span>
#             </button>
#            </a>
#           </div>
#          </div>
#          <div class="sc-f67e2d82-5 fYjbNv" data-testid="navigationPanel-navItem-level2">
#           <div class="sc-4befc967-0 bUlrPj">
#            <a class="sc-4befc967-1 gzOvMy" data-testid="internal-link" href="/future-planet/sustainable-business">
#             <button class="sc-f67e2d82-2 cPpMFZ" data-testid="level2NavButton-/future-planet/sustainable-business">
#              <span class="sc-f67e2d82-3 lhGSRJ" data-testid="level2NavText-/future-planet/sustainable-business">
#               Sustainable Business
#              </span>
#             </button>
#            </a>
#           </div>
#          </div>
#          <div class="sc-f67e2d82-5 fYjbNv" data-testid="navigationPanel-navItem-level2">
#           <div class="sc-4befc967-0 bUlrPj">
#            <a class="sc-4befc967-1 gzOvMy" data-testid="internal-link" href="/future-planet/green-living">
#             <button class="sc-f67e2d82-2 cPpMFZ" data-testid="level2NavButton-/future-planet/green-living">
#              <span class="sc-f67e2d82-3 lhGSRJ" data-testid="level2NavText-/future-planet/green-living">
#               Green Living
#              </span>
#             </button>
#            </a>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="sc-f67e2d82-5 hpFPKZ" data-testid="navigationPanel-navItem-level1">
#        <div class="sc-4befc967-0 bUlrPj">
#         <a class="sc-4befc967-1 gzOvMy" data-testid="internal-link" href="/video">
#          <button class="sc-f67e2d82-2 hqnDbU" data-testid="level1NavButton-/video">
#           <span class="sc-f67e2d82-3 lhGSRJ" data-testid="level1NavText-/video">
#            Video
#           </span>
#          </button>
#         </a>
#        </div>
#       </div>
#       <div class="sc-f67e2d82-5 hpFPKZ" data-testid="navigationPanel-navItem-level1">
#        <div>
#         <button class="sc-f67e2d82-2 hqnDbU" data-testid="level1NavButton-/live">
#          <span class="sc-f67e2d82-3 lhGSRJ" data-testid="level1NavText-/live">
#           Live
#          </span>
#          <div class="sc-f67e2d82-1 ougvF" data-testid="menuItem-ChevronIconWrapper-/live">
#           <svg category="arrows" class="sc-200855d3-0 hTnynj" data-testid="menuItem-ChevronIcon-/live" height="1em" icon="chevron-down" viewbox="0 0 32 32" width="1em">
#            <path d="M17.7 22.6.9 4.2v6.7L16 27.8 31.1 11V4.3L14.3 22.6h3.4zm0 0L.9 4.2v6.7L16 27.8 31.1 11V4.3L14.3 22.6h3.4z">
#            </path>
#           </svg>
#          </div>
#         </button>
#         <div class="sc-f67e2d82-4 dFtMiT" data-testid="level1NavContent-/live">
#          <div class="sc-f67e2d82-5 fYjbNv" data-testid="navigationPanel-navItem-level2">
#           <div class="sc-4befc967-0 bUlrPj">
#            <a class="sc-4befc967-1 gzOvMy" data-testid="internal-link" href="/live">
#             <button class="sc-f67e2d82-2 cPpMFZ" data-testid="level2NavButton-/live/live">
#              <span class="sc-f67e2d82-3 lhGSRJ" data-testid="level2NavText-/live/live">
#               Live
#              </span>
#             </button>
#            </a>
#           </div>
#          </div>
#          <div class="sc-f67e2d82-5 fYjbNv" data-testid="navigationPanel-navItem-level2">
#           <div class="sc-4befc967-0 bUlrPj">
#            <a class="sc-4befc967-1 gzOvMy" data-testid="internal-link" href="/live/news">
#             <button class="sc-f67e2d82-2 cPpMFZ" data-testid="level2NavButton-/live/news">
#              <span class="sc-f67e2d82-3 lhGSRJ" data-testid="level2NavText-/live/news">
#               Live News
#              </span>
#             </button>
#            </a>
#           </div>
#          </div>
#          <div class="sc-f67e2d82-5 fYjbNv" data-testid="navigationPanel-navItem-level2">
#           <div class="sc-4befc967-0 bUlrPj">
#            <a class="sc-4befc967-1 gzOvMy" data-testid="internal-link" href="/live/sport">
#             <button class="sc-f67e2d82-2 cPpMFZ" data-testid="level2NavButton-/live/sport">
#              <span class="sc-f67e2d82-3 lhGSRJ" data-testid="level2NavText-/live/sport">
#               Live Sport
#              </span>
#             </button>
#            </a>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="sc-f67e2d82-5 hpFPKZ" data-testid="navigationPanel-navItem-level1">
#        <a class="sc-4befc967-1 gzOvMy" href="https://www.bbc.co.uk/sounds" target="_self">
#         <button class="sc-f67e2d82-2 hqnDbU" data-testid="level1NavButton-https://www.bbc.co.uk/sounds">
#          <span data-testid="level1NavText-https://www.bbc.co.uk/sounds">
#           Audio
#          </span>
#         </button>
#        </a>
#       </div>
#      </div>
#     </div>
#     <!--$!-->
#     <!--/$-->
#    </main>
#   </div>
#   <script id="__NEXT_DATA__" type="application/json">
#    {"props":{"pageProps":{"authInfo":{"signInUrl":"https://session.bbc.com/session","signOutUrl":"https://account.bbc.com/signout","registerUrl":"https://session.bbc.com/session?action=register","statusUrl":"https://account.bbc.com/account","idSignedInCookieName":"ckns_id","accessTokenRefreshUrl":"https://session.bbc.com/session?ptrt=https%3A%2F%2Fsession.bbc.com%2Fsession%2Fannounce","accessTokenExpiredAt":0,"displayName":""},"mainNavigation":[{"id":"667d8ba9-ecc3-4b9b-88c2-613c2c5ee911","title":"Home","isSpecial":false,"slug":"home","path":"/home","externalTarget":"_self","subMenus":[]},{"id":"d0731524-f6da-42c7-80b5-f759e190f219","title":"News","isSpecial":false,"slug":"news","path":"/news","externalTarget":"_self","subMenus":[{"id":"767df23c-93da-4a2d-9e43-9e0cbfd8571d","title":"News","isSpecial":false,"slug":"news","path":"/news","externalTarget":"_self","subMenus":[]},{"id":"5e5cd8cf-5aed-41f1-92a2-60db9bc12173","title":"Israel-Gaza War","isSpecial":false,"slug":"israel-gaza-war","path":"/news/topics/c2vdnvdg6xxt","externalTarget":"_self","subMenus":[]},{"id":"e135f9bc-1c9b-4f05-8b45-b97c5ddeae5e","title":"War in Ukraine","isSpecial":false,"slug":"war-in-ukraine","path":"/news/war-in-ukraine","externalTarget":"_self","subMenus":[]},{"id":"345ce1af-35c4-4b26-9efd-3c3753bef12e","title":"World","isSpecial":false,"slug":"world","path":"/news/world","externalTarget":"_self","subMenus":[{"id":"dc7e63c6-9df9-4049-a28b-3458a0a10755","title":"World","isSpecial":false,"slug":"world","path":"/news/world","externalTarget":"_self","subMenus":[]},{"id":"d6d53354-ca51-428e-adbd-c4c5f59a9bf4","title":"Africa","isSpecial":false,"slug":"africa","path":"/news/world/africa","externalTarget":"_self","subMenus":[]},{"id":"3ebf2114-9c3c-4a41-9682-215afe25f0fb","title":"Asia","isSpecial":false,"slug":"asia","path":"/news/world/asia","externalTarget":"_self","subMenus":[{"id":"1aefa09b-d45f-4a40-a6b8-484aba029da7","title":"China","isSpecial":false,"slug":"china","path":"/news/world/asia/china","externalTarget":"_self","subMenus":[]},{"id":"87799cc2-9cfd-4051-b269-55569605e757","title":"India","isSpecial":false,"slug":"india","path":"/news/world/asia/india","externalTarget":"_self","subMenus":[]}]},{"id":"25edefb3-ab95-4a52-adf8-babf8c34d202","title":"Australia","isSpecial":false,"slug":"australia","path":"/news/world/australia","externalTarget":"_self","subMenus":[]},{"id":"d0f403f2-ee4a-421f-b42d-9388dbc32d7b","title":"Europe","isSpecial":false,"slug":"europe","path":"/news/world/europe","externalTarget":"_self","subMenus":[]},{"id":"c47bddb3-ccd3-4eaf-8031-12aae8866a78","title":"Latin America","isSpecial":false,"slug":"latin-america","path":"/news/world/latin_america","externalTarget":"_self","subMenus":[]},{"id":"ad01786e-8487-4931-b202-b87106d758d6","title":"Middle East","isSpecial":false,"slug":"middle-east","path":"/news/world/middle_east","externalTarget":"_self","subMenus":[]}]},{"id":"318a8f67-1d9d-4e74-905e-22019acfaf0c","title":"US \u0026 Canada","isSpecial":false,"slug":"us-canada","path":"/news/us-canada","externalTarget":"_self","subMenus":[]},{"id":"d2617d2c-c291-4f62-aad7-882c5f9e96e2","title":"UK","isSpecial":false,"slug":"uk","path":"/news/uk","externalTarget":"_self","subMenus":[]},{"id":"426a47d4-e3ad-4b65-a09f-6e40756be92a","title":"In Pictures","isSpecial":false,"slug":"in-pictures","path":"/news/in_pictures","externalTarget":"_self","subMenus":[]},{"id":"586b0c53-c078-4b3f-a9e5-c6d6774d05ab","title":"BBC Verify","isSpecial":false,"slug":"bbc-verify","path":"/news/reality_check","externalTarget":"_self","subMenus":[]}]},{"id":"f92a2a22-8280-4bee-b0c0-c8b747e95bef","title":"Sport","isSpecial":false,"slug":"sport","path":"/sport","externalTarget":"_self","subMenus":[]},{"id":"02f2e67a-8ef3-4630-a933-686c71e84fad","title":"Business","isSpecial":false,"slug":"business","path":"/business","externalTarget":"_self","subMenus":[{"id":"b3457121-7317-4d9f-b8be-c5b4e58a3ed6","title":"Business","isSpecial":false,"slug":"business","path ...
#   </script>
#  </body>
# </html>

# %%
cont = soup.find_all(class_="eNHMic")
titulos = []
descripciones = []
for e in cont:
  titulos.append(e.find("h2").get_text())
  descripciones.append(e.find("p").get_text())
df = pd.DataFrame({"titulo":titulos, "descripcion": descripciones})
df
# Out:
#                                               titulo  \
# 0  This is what America's busiest travel days loo...
# 1       Gaza Strip in maps: Life in Gaza under siege
# 2  'Blackout Wednesday' prompts drink-driving war...
# 3   Dutch vote for new leaders in neck-and-neck race
# 4  Stories of the hostages taken by Hamas from Is...
# 5   Hostages deal raise hopes and fears for families
# 6  Russian authorities crack down on abortion access
# 7  US set for busiest travel day as weather fears...
# 8  Biden pardons Thanksgiving turkeys on his birt...
#
#                                          descripcion
# 0  Officials expect nearly 30 million passengers ...
# 1  Find out more about what it is like to live in...
# 2  The night before Thanksgiving brings a spike o...
# 3  The head of the centre right, Dilan Yesilgöz, ...
# 4  From elderly grandparents to young children, t...
# 5  Relatives of those held anxiously wait to see ...
# 6  Authorities in Russia are aiming to limit abor...
# 7  Wintry conditions in the east are forecast to ...
# 8  The US president pardoned Liberty and Bell, an...

# %%
url = 'https://www.bbc.com/news/world'
user_agent = UserAgent()
response = requests.get(url, headers = {'user-agent':user_agent.edge})
if response.status_code == 200:
    html_content = response.text
else:
    html_content = ""
soup = BeautifulSoup(html_content, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width" name="viewport"/>
#   <title>
#    World - BBC News
#   </title>
#   <meta content="World - BBC News" property="og:title"/>
#   <meta content="World - BBC News" name="twitter:title"/>
#   <meta content="Get the latest BBC World News: international news, features and analysis from Africa, the Asia-Pacific, Europe, Latin America, the Middle East, South Asia, and the United States and Canada." name="description"/>
#   <meta content="Get the latest BBC World News: international news, features and analysis from Africa, the Asia-Pacific, Europe, Latin America, the Middle East, South Asia, and the United States and Canada." property="og:description"/>
#   <meta content="Get the latest BBC World News: international news, features and analysis from Africa, the Asia-Pacific, Europe, Latin America, the Middle East, South Asia, and the United States and Canada." name="twitter:description"/>
#   <meta content="#da532c" name="msapplication-TileColor"/>
#   <meta content="#ffffff" name="theme-color"/>
#   <meta content="noindex, nofollow" name="robots"/>
#   <link href="/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
#   <link href="/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
#   <link href="/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
#   <link href="/favicon.ico" rel="alternate icon"/>
#   <link href="/site.webmanifest" rel="manifest"/>
#   <link color="#000000" href="/safari-pinned-tab.svg" rel="mask-icon"/>
#   <link href="https://www.bbc.com/news/world" rel="canonical"/>
#   <link data-testid="en-gb-hreflang-tag" href="https://www.bbc.co.uk/news/world" hreflang="en-gb" rel="alternate"/>
#   <meta content="0.17.2+2" name="version"/>
#   <script type="application/ld+json">
#    {"@context":"http://schema.org","@type":"WebPage","description":"Get the latest BBC World News: international news, features and analysis from Africa, the Asia-Pacific, Europe, Latin America, the Middle East, South Asia, and the United States and Canada.","url":"https://www.bbc.com/news/world","mainEntityOfPage":"https://www.bbc.com/news/world","publisher":{"@type":"NewsMediaOrganization","name":"BBC News","logo":"https://m.files.bbci.co.uk/modules/bbc-morph-news-waf-page-meta/5.3.0/bbc_news_logo.png","publishingPrinciples":"https://www.bbc.co.uk/news/help-41670342"},"name":"World - BBC News"}
#   </script>
#   <meta content="21" name="next-head-count"/>
#   <link as="font" crossorigin="anonymous" href="/bbcx/_next/static/media/d5f96954169f3679.p.woff" rel="preload" type="font/woff"/>
#   <link as="font" crossorigin="anonymous" href="/bbcx/_next/static/media/f62d67caf3a51aea.p.woff" rel="preload" type="font/woff"/>
#   <link as="font" crossorigin="anonymous" href="/bbcx/_next/static/media/b5808b4cd433286b.p.woff" rel="preload" type="font/woff"/>
#   <link as="font" crossorigin="anonymous" href="/bbcx/_next/static/media/b3cc10788a0e66eb.p.woff" rel="preload" type="font/woff"/>
#   <link as="font" crossorigin="anonymous" href="/bbcx/_next/static/media/2d4795d021bab986.p.woff" rel="preload" type="font/woff"/>
#   <link as="font" crossorigin="anonymous" href="/bbcx/_next/static/media/48f9d2711a8d7b17.p.woff" rel="preload" type="font/woff"/>
#   <link as="font" crossorigin="anonymous" href="/bbcx/_next/static/media/d1557e5f46f77917.p.woff" rel="preload" type="font/woff"/>
#   <link as="font" crossorigin="anonymous" href="/bbcx/_next/static/media/96161a9bfe151a00.p.woff" rel="preload" type="font/woff"/>
#   <link as="font" crossorigin="anonymous" href="/bbcx/_next/static/media/0d9d619a2d57fba4.p.woff" rel="preload" type="font/woff"/>
#   <link as="font" crossorigin="anonymous" href="/bbcx/_next/static/media/127e830343b9db2c.p.woff" rel="preload" type="font/woff"/>
#   <link as="font" crossorigin="anonymous" href="/bbcx/_next/static/media/5c1db66e66eaee0e.p.woff" rel="preload" type="font/woff"/>
#   <link as="font" crossorigin="anonymous" href="/bbcx/_next/static/media/6bd602911783b8b0.p.woff" rel="preload" type="font/woff"/>
#   <link as="font" crossorigin="anonymous" href="/bbcx/_next/static/media/b36f6bac73b2c645.p.woff" rel="preload" type="font/woff"/>
#   <link as="font" crossorigin="anonymous" href="/bbcx/_next/static/media/7328d574a2e5bccc.p.woff" rel="preload" type="font/woff"/>
#   <link as="font" crossorigin="anonymous" href="/bbcx/_next/static/media/6de3099f2481c296.p.woff" rel="preload" type="font/woff"/>
#   <link as="font" crossorigin="anonymous" href="/bbcx/_next/static/media/b36685b86da40a03.p.woff" rel="preload" type="font/woff"/>
#   <link as="font" crossorigin="anonymous" href="/bbcx/_next/static/media/e8223b3afcb82cf6.p.woff" rel="preload" type="font/woff"/>
#   <link as="font" crossorigin="anonymous" href="/bbcx/_next/static/media/33acc70dd32e194a.p.woff" rel="preload" type="font/woff"/>
#   <link as="font" crossorigin="anonymous" href="/bbcx/_next/static/media/70829e37664a6fd3.p.woff" rel="preload" type="font/woff"/>
#   <link as="font" crossorigin="anonymous" href="/bbcx/_next/static/media/2bd6dac86b11d814.p.woff" rel="preload" type="font/woff"/>
#   <script async="" data-nscript="beforeInteractive" id="inline-dotcom">
#    window.dotcom = window.dotcom || { cmd: [] }; window.dotcomConfig = { pageAds: true, playerAds: true, xPlatform: true };
#   </script>
#   <script async="" data-nscript="beforeInteractive" id="inline-googletag">
#    window.googletag = window.googletag || { cmd: [] };
#   </script>
#   <link as="style" href="/bbcx/_next/static/css/d33e6c14cf3d6d34.css" rel="preload"/>
#   <link data-n-g="" href="/bbcx/_next/static/css/d33e6c14cf3d6d34.css" rel="stylesheet"/>
#   <noscript data-n-css="">
#   </noscript>
#   <script defer="" nomodule="" src="/bbcx/_next/static/chunks/polyfills-c67a75d1b6f99dc8.js">
#   </script>
#   <script async="" data-nscript="beforeInteractive" defer="" id="requirejs-script" src="https://static.bbci.co.uk/frameworks/requirejs/0.13.0/sharedmodules/require.js" type="text/javascript">
#   </script>
#   <script async="" data-nscript="beforeInteractive" defer="" id="ads-service-script" src="https://gn-web-assets.api.bbc.com/ngas/latest/dotcom-bootstrap.js" type="module">
#   </script>
#   <script async="" data-nscript="beforeInteractive" defer="" id="inline-block-ads" src="/blockAdBlock.js">
#   </script>
#   <script async="" data-nscript="beforeInteractive" defer="" id="inline-prebid-ads" src="/prebid-ads.js">
#   </script>
#   <script async="" data-nscript="beforeInteractive" defer="" id="bump-script" src="https://emp.bbci.co.uk/emp/bump-4/bump-4.js" type="text/javascript">
#   </script>
#   <script defer="" src="/bbcx/_next/static/chunks/webpack-29bbea4c57b4d594.js">
#   </script>
#   <script defer="" src="/bbcx/_next/static/chunks/framework-3adfd9c6527e6ba9.js">
#   </script>
#   <script defer="" src="/bbcx/_next/static/chunks/main-2dc0acb15c3c6316.js">
#   </script>
#   <script defer="" src="/bbcx/_next/static/chunks/pages/_app-d81749f32e3e5a60.js">
#   </script>
#   <script defer="" src="/bbcx/_next/static/chunks/pages/%5B%5B...slug%5D%5D-c28223db78396f64.js">
#   </script>
#   <script defer="" src="/bbcx/_next/static/9pcLmBH09sLE8N14cwNhS/_buildManifest.js">
#   </script>
#   <script defer="" src="/bbcx/_next/static/9pcLmBH09sLE8N14cwNhS/_ssgManifest.js">
#   </script>
#   <style data-styled="" data-styled-version="5.3.11">
#    html,body,div,span,applet,object,iframe,h1,h2,h3,h4,h5,h6,p,blockquote,pre,a,abbr,acronym,address,big,cite,code,del,dfn,em,img,ins,kbd,q,s,samp,small,strike,strong,sub,sup,tt,var,b,u,i,center,dl,dt,dd,ol,ul,li,fieldset,form,label,legend,table,caption,tbody,tfoot,thead,tr,th,td,article,aside,canvas,details,embed,figure,figcaption,footer,header,hgroup,main,menu,nav,output,ruby,section,summary,time,mark,audio,video{margin:0;padding:0;border:0;font:inherit;vertical-align:baseline;}/*!sc*/
# article,aside,details,figcaption,figure,footer,header,hgroup,main,menu,nav,section{display:block;}/*!sc*/
# body{line-height:1;}/*!sc*/
# @supports (-webkit-text-size-adjust:none) or (text-size-adjust:none){body{-webkit-text-size-adjust:none;text-size-adjust:none;}}/*!sc*/
# ol,ul{list-style:none;}/*!sc*/
# blockquote,q{quotes:none;}/*!sc*/
# blockquote::before,blockquote::after,q::before,q::after{content:'';}/*!sc*/
# table{border-collapse:collapse;border-spacing:0;}/*!sc*/
# button{-webkit-appearance:none;-moz-appearance:none;appearance:none;margin:0;padding:0;background:none;border-radius:0;border:0;font-family:inherit;color:inherit;}/*!sc*/
# data-styled.g1[id="sc-global-igImlZ1"]{content:"sc-global-igImlZ1,"}/*!sc*/
# .gXZDla{box-sizing:border-box;display:grid;gap:16px;margin:0 auto;width:1248px;}/*!sc*/
# @media screen and (max-width:1279px){.gXZDla{margin:0 16px;width:auto;}}/*!sc*/
# @media screen and (max-width:767px){.gXZDla{margin:0 16px;width:auto;}}/*!sc*/
# @media screen and (max-width:599px){.gXZDla{margin:0;width:auto;}}/*!sc*/
# @media screen and (max-width:8192px){}/*!sc*/
# @media screen and (max-width:1279px){}/*!sc*/
# @media screen and (max-width:1007px){}/*!sc*/
# @media screen and (max-width:767px){}/*!sc*/
# @media screen and (max-width:599px){}/*!sc*/
# @media screen and (max-width:399px){}/*!sc*/
# data-styled.g3[id="sc-4e574cd-0"]{content:"gXZDla,"}/*!sc*/
# .dckLVJ{display:grid;box-sizing:border-box;-webkit-align-items:start;-webkit-box-align:start;-ms-flex-align:start;align-items:start;}/*!sc*/
# @media screen and (max-width:8192px){.dckLVJ{grid-gap:16px;margin:0 0 8px 0;grid-row:1 / span 1;grid-column:1 / span 1;}}/*!sc*/
# @media screen and (max-width:1279px){.dckLVJ{grid-gap:16px;margin:0 0 8px 0;grid-row:1 / span 1;grid-column:1 / span 1;}}/*!sc*/
# @media screen and (max-width:1007px){.dckLVJ{grid-gap:16px;margin:0 0 16px 0;grid-row:1 / span 1;grid-column:1 / span 1;}}/*!sc*/
# @media screen and (max-width:767px){.dckLVJ{grid-gap:16px;margin:0 0 16px 0;grid-row:1 / span 1;grid-column:1 / span 2;}}/*!sc*/
# @media screen and (max-width:599px){.dckLVJ{grid-gap:16px;margin:0 0 16px 0;grid-row:1 / span 1;grid-column:1 / span 2;}}/*!sc*/
# @media screen and (max-width:399px){.dckLVJ{grid-gap:16px;margin:0 0 16px 0;grid-row:1 / span 1;grid-column:1 / span 2;}}/*!sc*/
# .ckmhTf{display:grid;box-sizing:border-box;-webkit-align-items:start;-webkit-box-align:start;-ms-flex-align:start;align-items:start;}/*!sc*/
# @media screen and (max-width:8192px){.ckmhTf{grid-gap:16px;grid-row:1 / span 1;grid-column:2 / span 1;}}/*!sc*/
# @media screen and (max-width:1279px){.ckmhTf{grid-gap:16px;grid-row:1 / span 1;grid-column:2 / span 1;}}/*!sc*/
# @media screen and (max-width:1007px){.ckmhTf{grid-gap:16px;grid-row:1 / span 1;grid-column:2 / span 1;}}/*!sc*/
# @media screen and (max-width:767px){.ckmhTf{grid-gap:16px;grid-row:4 / span 1;grid-column:1 / span 2;}}/*!sc*/
# @media screen and (max-width:599px){.ckmhTf{grid-gap:16px;grid-row:4 / span 1;grid-column:1 / span 2;}}/*!sc*/
# @media screen and (max-width:399px){.ckmhTf{grid-gap:16px;grid-row:4 / span 1;grid-column:1 / span 2;}}/*!sc*/
# .dnpSXe{display:grid;box-sizing:border-box;-webkit-align-items:start;-webkit-box-align:start;-ms-flex-align:start;align-items:start;}/*!sc*/
# @media screen and (max-width:8192px){.dnpSXe{grid-gap:16px;grid-row:2 / span 2;grid-column:2 / span 1;}}/*!sc*/
# @media screen and (max-width:1279px){.dnpSXe{grid-gap:16px;grid-row:2 / span 2;grid-column:2 / span 1;}}/*!sc*/
# @media screen and (max-width:1007px){.dnpSXe{grid-gap:16px;grid-row:2 / span 2;grid-column:2 / span 1;}}/*!sc*/
# @media screen and (max-width:767px){.dnpSXe{grid-gap:16px;grid-row:5 / span 1;grid-column:1 / span 2;}}/*!sc*/
# @media screen and (max-width:599px){.dnpSXe{grid-gap:16px;grid-row:5 / span 1;grid-column:1 / span 2;}}/*!sc*/
# @media screen and (max-width:399px){.dnpSXe{grid-gap:16px;grid-row:5 / span 1;grid-column:1 / span 2;}}/*!sc*/
# .jOSbIh{display:grid;box-sizing:border-box;-webkit-align-items:start;-webkit-box-align:start;-ms-flex-align:start;align-items:start;}/*!sc*/
# @media screen and (max-width:8192px){.jOSbIh{grid-template-columns:repeat(3,1fr);grid-gap:16px;grid-row:2 / span 1;grid-column:1 / span 1;}}/*!sc*/
# @media screen and (max-width:1279px){.jOSbIh{grid-template-columns:repeat(3,1fr);grid-gap:16px;grid-row:2 / span 1;grid-column:1 / span 1;}}/*!sc*/
# @media screen and (max-width:1007px){.jOSbIh{grid-template-columns:repeat(2,1fr);grid-gap:16px;grid-row:2 / span 2;grid-column:1 / span 1;}}/*!sc*/
# @media screen and (max-width:767px){.jOSbIh{grid-template-columns:repeat(2,1fr);grid-gap:16px;grid-row:2 / span 2;grid-column:1 / span 2;}}/*!sc*/
# @media screen and (max-width:599px){.jOSbIh{grid-template-columns:repeat(1,1fr);grid-gap:16px;grid-row:2 / span 1;grid-column:1 / span 2;}}/*!sc*/
# @media screen and (max-width:399px){.jOSbIh{grid-template-columns:repeat(1,1fr);grid-gap:16px;grid-row:2 / span 1;grid-column:1 / span 2;}}/*!sc*/
# .fvGkoc{display:grid;box-sizing:border-box;}/*!sc*/
# @media screen and (max-width:8192px){.fvGkoc{grid-template-columns:repeat(5,1fr);grid-template-rows:auto;grid-gap:16px;margin:0 16px;}}/*!sc*/
# @media screen and (max-width:1279px){.fvGkoc{grid-template-columns:repeat(5,1fr);grid-template-rows:auto;grid-gap:16px;margin:0 16px;}}/*!sc*/
# @media screen and (max-width:1007px){.fvGkoc{grid-template-columns:repeat(3,1fr);grid-template-rows:auto;grid-gap:16px;margin:0 16px;}}/*!sc*/
# @media screen and (max-width:767px){.fvGkoc{grid-template-columns:repeat(2,1fr);grid-template-rows:auto;grid-gap:16px;margin:0 16px;}}/*!sc*/
# @media screen and (max-width:599px){.fvGkoc{grid-template-columns:repeat(1,1fr);grid-template-rows:auto;grid-gap:16px;margin:0 16px;}}/*!sc*/
# @media screen and (max-width:399px){.fvGkoc{grid-template-columns:repeat(1,1fr);grid-template-rows:auto;grid-gap:16px;margin:0 16px;}}/*!sc*/
# .dzHQkZ{display:grid;box-sizing:border-box;}/*!sc*/
# @media screen and (max-width:8192px){.dzHQkZ{grid-template-columns:repeat(1,1fr);grid-gap:24px;}}/*!sc*/
# @media screen and (max-width:1279px){.dzHQkZ{grid-template-columns:repeat(1,1fr);grid-gap:24px;}}/*!sc*/
# @media screen and (max-width:1007px){.dzHQkZ{grid-template-columns:repeat(1,1fr);grid-gap:24px;}}/*!sc*/
# @media screen and (max-width:767px){.dzHQkZ{grid-template-columns:repeat(1,1fr);grid-gap:24px;}}/*!sc*/
# @media screen and (max-width:599px){.dzHQkZ{grid-template-columns:repeat(1,1fr);grid-gap:16px;}}/*!sc*/
# @media screen and (max-width:399px){.dzHQkZ{grid-template-columns:repeat(1,1fr);grid-gap:16px;}}/*!sc*/
# data-styled.g4[id="sc-5b94fa74-0"]{content:"dckLVJ,ckmhTf,dnpSXe,jOSbIh,fvGkoc,dzHQkZ,"}/*!sc*/
# .gzOvMy{-webkit-text-decoration:none;text-decoration:none;cursor:pointer;color:unset;}/*!sc*/
# data-styled.g6[id="sc-4befc967-1"]{content:"gzOvMy,"}/*!sc*/
# .jQYtVJ{position:relative;line-height:0;}/*!sc*/
# data-styled.g8[id="sc-72a8a9a8-0"]{content:"jQYtVJ,"}/*!sc*/
# .cVIWlY{width:100%;object-fit:contain;background:url(https://ichef.bbci.co.uk/images/ic/raw/p0fxw69t.png) no-repeat;background-size:contain;}/*!sc*/
# data-styled.g10[id="sc-8d5354b4-0"]{content:"cVIWlY,"}/*!sc*/
# .kUFdej{-webkit-text-decoration:underline;text-decoration:underline;color:#202224;font-family:'__reithSerif_3e9265', Helvetica,Arial,sans-serif;font-weight:500;font-size:18px;line-height:26px;text-transform:none;-webkit-text-decoration:underline;text-decoration:underline;-webkit-letter-spacing:-0.36px;-moz-letter-spacing:-0.36px;-ms-letter-spacing:-0.36px;letter-spacing:-0.36px;}/*!sc*/
# @media screen and (max-width:399px){.kUFdej{font-family:'__reithSerif_3e9265', Helvetica,Arial,sans-serif;font-weight:500;font-size:16px;line-height:24px;text-transform:none;-webkit-text-decoration:underline;text-decoration:underline;-webkit-letter-spacing:-0.32px;-moz-letter-spacing:-0.32px;-ms-letter-spacing:-0.32px;letter-spacing:-0.32px;}}/*!sc*/
# @media screen and (max-width:599px){.kUFdej{font-family:'__reithSerif_3e9265', Helvetica,Arial,sans-serif;font-weight:500;font-size:16px;line-height:24px;text-transform:none;-webkit-text-decoration:underline;text-decoration:underline;-webkit-letter-spacing:-0.32px;-moz-letter-spacing:-0.32px;-ms-letter-spacing:-0.32px;letter-spacing:-0.32px;}}/*!sc*/
# data-styled.g11[id="sc-c9299ecf-0"]{content:"kUFdej,"}/*!sc*/
# .gDEGTg{color:#202224;font-family:'__reithSerif_3e9265', Helvetica,Arial,sans-serif;font-weight:400;font-size:18px;line-height:26px;text-transform:none;-webkit-text-decoration:none;text-decoration:none;-webkit-letter-spacing:-0.36px;-moz-letter-spacing:-0.36px;-ms-letter-spacing:-0.36px;letter-spacing:-0.36px;}/*!sc*/
# @media screen and (max-width:399px){.gDEGTg{font-family:'__reithSerif_3e9265', Helvetica,Arial,sans-serif;font-weight:400;font-size:16px;line-height:24px;text-transform:none;-webkit-text-decoration:none;text-decoration:none;-webkit-letter-spacing:-0.32px;-moz-letter-spacing:-0.32px;-ms-letter-spacing:-0.32px;letter-spacing:-0.32px;}}/*!sc*/
# @media screen and (max-width:599px){.gDEGTg{font-family:'__reithSerif_3e9265', Helvetica,Arial,sans-serif;font-weight:400;font-size:16px;line-height:24px;text-transform:none;-webkit-text-decoration:none;text-decoration:none;-webkit-letter-spacing:-0.32px;-moz-letter-spacing:-0.32px;-ms-letter-spacing:-0.32px;letter-spacing:-0.32px;}}/*!sc*/
# data-styled.g13[id="sc-eb7bd5f6-0"]{content:"gDEGTg,"}/*!sc*/
# .kKcaog{font-style:italic;}/*!sc*/
# @media screen and (max-width:599px){.kKcaog{word-break:break-word;}}/*!sc*/
# .kVRnKf{font-weight:600;}/*!sc*/
# @media screen and (max-width:599px){.kVRnKf{word-break:break-word;}}/*!sc*/
# data-styled.g16[id="sc-7dcfb11b-0"]{content:"kKcaog,kVRnKf,"}/*!sc*/
# .kBCmpn{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# .kBCmpn svg{width:100%;height:100%;}/*!sc*/
# data-styled.g18[id="sc-e41ce09d-0"]{content:"kBCmpn,"}/*!sc*/
# .eswlvd{cursor:pointer;font-weight:500;padding:6px 12px 6px 12px;border:2px solid transparent;outline:2px solid transparent;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;-webkit-column-gap:9.3px;column-gap:9.3px;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;box-sizing:border-box;font-family:'__reithSans_aa0e4a', Helvetica,Arial,sans-serif;font-weight:500;font-size:16px;line-height:18px;text-transform:none;-webkit-text-decoration:none;text-decoration:none;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;}/*!sc*/
# data-styled.g20[id="sc-e41ce09d-2"]{content:"eswlvd,"}/*!sc*/
# .jmLRHZ{background-color:#000000;color:#ffffff;border-color:#000000;outline-color:#000000;}/*!sc*/
# .jmLRHZ:hover{background-color:#3a3c3e;border-color:#3a3c3e;outline-color:#3a3c3e;}/*!sc*/
# .jmLRHZ:focus{outline:2px solid #000000;border:2px solid #ffffff;}/*!sc*/
# .jmLRHZ:active{background-color:#000000;color:#ffffff;border-color:#000000;outline-color:#000000;}/*!sc*/
# .jmLRHZ:disabled,.jmLRHZ[disabled]{cursor:not-allowed;background-color:#d2d4d6;color:#8a8c8e;outline-color:#d2d4d6;border-color:#d2d4d6;}/*!sc*/
# data-styled.g21[id="sc-e41ce09d-3"]{content:"jmLRHZ,"}/*!sc*/
# .iHqyyW{border-bottom:1px solid #e6e8ea;-webkit-transition:opacity 0.2s ease-in-out;transition:opacity 0.2s ease-in-out;grid-auto-rows:auto auto 1fr auto;position:relative;display:grid;opacity:1;}/*!sc*/
# .iHqyyW:hover img{opacity:0.8;}/*!sc*/
# .iHqyyW:hover h3{-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# data-styled.g48[id="sc-2c2f2429-0"]{content:"iHqyyW,"}/*!sc*/
# .cBPOQE{position:relative;}/*!sc*/
# data-styled.g49[id="sc-2c2f2429-1"]{content:"cBPOQE,"}/*!sc*/
# .zMPQE{height:100%;width:100%;}/*!sc*/
# .zMPQE img{aspect-ratio:16 / 9;object-fit:cover;}/*!sc*/
# data-styled.g50[id="sc-2c2f2429-2"]{content:"zMPQE,"}/*!sc*/
# .bmuaxk{background-color:#ffffff;color:#ffffff;grid-gap:12px;display:grid;padding-top:8px;}/*!sc*/
# data-styled.g51[id="sc-2c2f2429-3"]{content:"bmuaxk,"}/*!sc*/
# .loBKGz{color:#202224;font-family:'__reithSerif_3e9265', Helvetica,Arial,sans-serif;font-weight:400;font-size:14px;line-height:18px;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;}/*!sc*/
# @media screen and (max-width:599px){.loBKGz{font-family:'__reithSerif_3e9265', Helvetica,Arial,sans-serif;font-weight:400;font-size:14px;line-height:18px;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;}}/*!sc*/
# data-styled.g52[id="sc-2c2f2429-4"]{content:"loBKGz,"}/*!sc*/
# .bhsGjX{font-family:'__reithSerif_3e9265', Helvetica,Arial,sans-serif;font-weight:400;font-size:14px;line-height:18px;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;color:#202224;margin-bottom:56px;}/*!sc*/
# @media screen and (max-width:599px){.bhsGjX{font-family:'__reithSerif_3e9265', Helvetica,Arial,sans-serif;font-weight:400;font-size:14px;line-height:18px;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;margin-bottom:48px;}}/*!sc*/
# data-styled.g66[id="sc-cee500c-0"]{content:"bhsGjX,"}/*!sc*/
# .jnuLQH{-webkit-align-items:start;-webkit-box-align:start;-ms-flex-align:start;align-items:start;display:grid;}/*!sc*/
# data-styled.g67[id="sc-cee500c-1"]{content:"jnuLQH,"}/*!sc*/
# .kjKWeB{height:100%;width:100%;}/*!sc*/
# .kjKWeB img{aspect-ratio:16 / 9;object-fit:cover;}/*!sc*/
# data-styled.g68[id="sc-cee500c-2"]{content:"kjKWeB,"}/*!sc*/
# .gFetrx{border-bottom:1px solid #e6e8ea;position:relative;min-height:190px;display:block;}/*!sc*/
# .jYkDce{border-bottom:none;position:relative;min-height:190px;display:block;}/*!sc*/
# data-styled.g69[id="sc-cee500c-3"]{content:"gFetrx,jYkDce,"}/*!sc*/
# .iYWEjl{grid-template-columns:90px 1fr;-webkit-align-items:stretch;-webkit-box-align:stretch;-ms-flex-align:stretch;align-items:stretch;position:relative;display:grid;gap:16px;}/*!sc*/
# .iYWEjl:hover img{opacity:0.8;}/*!sc*/
# .iYWEjl:hover h3{-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# @media screen and (max-width:599px){.iYWEjl{grid-template-columns:1fr;}}/*!sc*/
# data-styled.g70[id="sc-cee500c-4"]{content:"iYWEjl,"}/*!sc*/
# .fTtgb{margin-bottom:16px;position:relative;margin-left:16px;float:right;width:300px;}/*!sc*/
# @media screen and (max-width:599px){.fTtgb{margin-bottom:8px;margin-left:8px;width:50%;}}/*!sc*/
# data-styled.g71[id="sc-cee500c-5"]{content:"fTtgb,"}/*!sc*/
# .eNHMic{display:block;}/*!sc*/
# data-styled.g72[id="sc-cee500c-6"]{content:"eNHMic,"}/*!sc*/
# .fsjsPV{font-family:'__reithSerif_3e9265', Helvetica,Arial,sans-serif;font-weight:400;font-size:14px;line-height:18px;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;color:#202224;margin-bottom:4px;}/*!sc*/
# @media screen and (max-width:599px){.fsjsPV{font-family:'__reithSerif_3e9265', Helvetica,Arial,sans-serif;font-weight:400;font-size:14px;line-height:18px;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;margin-bottom:0;}}/*!sc*/
# data-styled.g73[id="sc-bcf5c03b-0"]{content:"fsjsPV,"}/*!sc*/
# .sjbHr{height:100%;width:100%;}/*!sc*/
# .sjbHr img{aspect-ratio:16 / 9;object-fit:cover;}/*!sc*/
# @media screen and (max-width:599px){.sjbHr{width:calc(100% + 32px);margin-right:-16px;margin-left:-16px;}}/*!sc*/
# data-styled.g74[id="sc-bcf5c03b-1"]{content:"sjbHr,"}/*!sc*/
# .bNrFQe{grid-template-columns:1fr 2fr;border-bottom:1px solid #e6e8ea;background-color:transparent;position:relative;padding:0;margin:0;grid-gap:16px;display:grid;}/*!sc*/
# .bNrFQe:hover img{opacity:0.8;}/*!sc*/
# .bNrFQe:hover h3{-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# @media screen and (max-width:1007px){.bNrFQe{grid-template-columns:1fr 3fr;grid-gap:12px;}}/*!sc*/
# @media screen and (max-width:767px){.bNrFQe{grid-template-columns:1fr;}}/*!sc*/
# @media screen and (max-width:599px){.bNrFQe{margin:0 -16px;padding:0 16px;}}/*!sc*/
# data-styled.g75[id="sc-bcf5c03b-2"]{content:"bNrFQe,"}/*!sc*/
# .fBQoMP{background-color:transparent;-webkit-align-items:stretch;-webkit-box-align:stretch;-ms-flex-align:stretch;align-items:stretch;position:relative;display:grid;grid-gap:0;}/*!sc*/
# @media screen and (max-width:1007px){.fBQoMP{grid-gap:16px;}}/*!sc*/
# @media screen and (max-width:599px){.fBQoMP{grid-gap:0;}}/*!sc*/
# data-styled.g76[id="sc-bcf5c03b-3"]{content:"fBQoMP,"}/*!sc*/
# .dTzowl{position:relative;-webkit-align-self:start;-ms-flex-item-align:start;align-self:start;-webkit-order:2;-ms-flex-order:2;order:2;}/*!sc*/
# @media screen and (max-width:767px){.dTzowl{-webkit-order:unset;-ms-flex-order:unset;order:unset;}}/*!sc*/
# data-styled.g77[id="sc-bcf5c03b-4"]{content:"dTzowl,"}/*!sc*/
# .lobrFA{-webkit-order:1;-ms-flex-order:1;order:1;grid-gap:12px;display:grid;-webkit-align-content:start;-ms-flex-line-pack:start;align-content:start;-webkit-align-items:start;-webkit-box-align:start;-ms-flex-align:start;align-items:start;}/*!sc*/
# data-styled.g78[id="sc-bcf5c03b-5"]{content:"lobrFA,"}/*!sc*/
# .bWGEXP{display:grid;grid-gap:12px;}/*!sc*/
# .bWGEXP > *:nth-child(2){border-top:1px solid #e6e8ea;padding-top:12px;}/*!sc*/
# data-styled.g79[id="sc-bcf5c03b-6"]{content:"bWGEXP,"}/*!sc*/
# .bNzKIA{font-family:'__reithSerif_3e9265', Helvetica,Arial,sans-serif;font-weight:400;font-size:14px;line-height:18px;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;color:#202224;margin-bottom:4px;}/*!sc*/
# @media screen and (max-width:599px){.bNzKIA{font-family:'__reithSerif_3e9265', Helvetica,Arial,sans-serif;font-weight:400;font-size:14px;line-height:18px;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;margin-bottom:0;}}/*!sc*/
# data-styled.g80[id="sc-6d72d12a-0"]{content:"bNzKIA,"}/*!sc*/
# .gmzJUh{border-bottom:1px solid #e6e8ea;position:relative;grid-gap:8px;display:grid;}/*!sc*/
# .gmzJUh:hover h3{-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# data-styled.g81[id="sc-6d72d12a-1"]{content:"gmzJUh,"}/*!sc*/
# .gnuanj{position:relative;grid-gap:8px;display:grid;}/*!sc*/
# data-styled.g82[id="sc-6d72d12a-2"]{content:"gnuanj,"}/*!sc*/
# .hYxbtM{margin-top:29px;}/*!sc*/
# @media screen and (max-width:399px){.hYxbtM{margin-top:24px;}}/*!sc*/
# @media screen and (max-width:599px){.hYxbtM{margin-top:24px;}}/*!sc*/
# data-styled.g119[id="sc-19b1eb93-0"]{content:"hYxbtM,"}/*!sc*/
# .fwyFkM{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;-webkit-column-gap:16px;column-gap:16px;row-gap:18px;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;}/*!sc*/
# @media screen and (max-width:399px){.fwyFkM{-webkit-align-items:flex-start;-webkit-box-align:flex-start;-ms-flex-align:flex-start;align-items:flex-start;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;row-gap:24px;-webkit-column-gap:0;column-gap:0;}}/*!sc*/
# @media screen and (max-width:599px){.fwyFkM{-webkit-align-items:flex-start;-webkit-box-align:flex-start;-ms-flex-align:flex-start;align-items:flex-start;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;row-gap:24px;-webkit-column-gap:0;column-gap:0;}}/*!sc*/
# data-styled.g120[id="sc-19b1eb93-1"]{content:"fwyFkM,"}/*!sc*/
# .kWeMlj{-webkit-text-decoration:none;text-decoration:none;position:relative;color:#000000;font-family:'__reithSans_aa0e4a', Helvetica,Arial,sans-serif;font-weight:500;font-size:14px;line-height:18px;text-transform:none;-webkit-text-decoration:none;text-decoration:none;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;}/*!sc*/
# .kWeMlj:hover{-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# data-styled.g121[id="sc-19b1eb93-2"]{content:"kWeMlj,"}/*!sc*/
# .bDkVIF{background-color:#00000033;display:none;top:0px;position:fixed;border:none;width:100%;bottom:0;z-index:3000;}/*!sc*/
# .bDkVIF *{z-index:3000;}/*!sc*/
# data-styled.g128[id="sc-d2d98e04-0"]{content:"bDkVIF,"}/*!sc*/
# .hgisAf{position:fixed;display:block;bottom:0;width:100%;background-color:#ffffff;z-index:3000;-webkit-transition:-webkit-transform 0.1s ease-in-out;-webkit-transition:transform 0.1s ease-in-out;transition:transform 0.1s ease-in-out;top:0px;left:0;width:320px;-webkit-transform:translateX(-100%);-ms-transform:translateX(-100%);transform:translateX(-100%);}/*!sc*/
# .hgisAf *{z-index:3000;}/*!sc*/
# @media screen and (max-width:599px){.hgisAf{width:100%;}}/*!sc*/
# data-styled.g129[id="sc-d2d98e04-1"]{content:"hgisAf,"}/*!sc*/
# .dzCnly{max-width:1280px;margin:16px auto 48px auto;padding-left:16px;}/*!sc*/
# data-styled.g130[id="sc-ba224a1-0"]{content:"dzCnly,"}/*!sc*/
# .cMQOuo{margin-top:16px;}/*!sc*/
# .cMQOuo p{font-family:'__reithSans_aa0e4a', Helvetica,Arial,sans-serif;font-weight:400;font-size:12px;line-height:16px;text-transform:none;-webkit-text-decoration:none;text-decoration:none;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;}/*!sc*/
# .cMQOuo b,.cMQOuo a{font-family:'__reithSans_aa0e4a', Helvetica,Arial,sans-serif;font-weight:700;font-size:12px;line-height:16px;text-transform:none;-webkit-text-decoration:none;text-decoration:none;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;}/*!sc*/
# .cMQOuo a{-webkit-text-decoration:none;text-decoration:none;color:#000000;}/*!sc*/
# @media screen and (max-width:599px){.cMQOuo{margin-top:24px;}}/*!sc*/
# data-styled.g131[id="sc-ba224a1-1"]{content:"cMQOuo,"}/*!sc*/
# .boQOzm{background-color:#3a3c3e;margin-top:16px;height:1px;border:none;}/*!sc*/
# .yUcMM{background-color:#e6e8ea;margin-top:16px;height:1px;border:none;}/*!sc*/
# data-styled.g132[id="sc-ba224a1-2"]{content:"boQOzm,yUcMM,"}/*!sc*/
# @media screen and (max-width:1279px){.fTBhwF{display:none;}}/*!sc*/
# data-styled.g133[id="sc-ba224a1-3"]{content:"fTBhwF,"}/*!sc*/
# .mcmMa{margin-top:0px;height:32px;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;gap:8px;}/*!sc*/
# @media screen and (max-width:399px){.mcmMa{margin-top:0px;}}/*!sc*/
# @media screen and (max-width:599px){.mcmMa{margin-top:0px;}}/*!sc*/
# .bBUimm{margin-top:4px;height:32px;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;gap:8px;}/*!sc*/
# @media screen and (max-width:399px){.bBUimm{margin-top:4px;}}/*!sc*/
# @media screen and (max-width:599px){.bBUimm{margin-top:4px;}}/*!sc*/
# .dGeSbp{margin-top:0px;height:auto;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;gap:8px;}/*!sc*/
# @media screen and (max-width:399px){.dGeSbp{display:none;}}/*!sc*/
# @media screen and (max-width:599px){.dGeSbp{display:none;}}/*!sc*/
# @media screen and (max-width:399px){.dGeSbp{margin-top:2px;}}/*!sc*/
# @media screen and (max-width:599px){.dGeSbp{margin-top:2px;}}/*!sc*/
# .dIiwqJ{margin-top:0px;height:32px;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;gap:8px;position:absolute;bottom:0;}/*!sc*/
# @media screen and (max-width:399px){.dIiwqJ{margin-top:2px;}}/*!sc*/
# @media screen and (max-width:599px){.dIiwqJ{margin-top:2px;}}/*!sc*/
# data-styled.g135[id="sc-ec7fe2bd-0"]{content:"mcmMa,bBUimm,dGeSbp,dIiwqJ,"}/*!sc*/
# .eIXzYS{font-family:'__reithSans_aa0e4a', Helvetica,Arial,sans-serif;font-weight:400;font-size:12px;line-height:14px;text-transform:none;-webkit-text-decoration:none;text-decoration:none;-webkit-letter-spacing:-0.12px;-moz-letter-spacing:-0.12px;-ms-letter-spacing:-0.12px;letter-spacing:-0.12px;color:#545658;}/*!sc*/
# .VpUCh{font-family:'__reithSans_aa0e4a', Helvetica,Arial,sans-serif;font-weight:400;font-size:12px;line-height:14px;text-transform:none;-webkit-text-decoration:none;text-decoration:none;-webkit-letter-spacing:-0.12px;-moz-letter-spacing:-0.12px;-ms-letter-spacing:-0.12px;letter-spacing:-0.12px;color:#545658;}/*!sc*/
# @media screen and (max-width:767px){.VpUCh{display:block;}}/*!sc*/
# @media screen and (max-width:1007px){.VpUCh{display:block;}}/*!sc*/
# @media screen and (max-width:1279px){.VpUCh{display:block;}}/*!sc*/
# @media screen and (max-width:8192px){.VpUCh{display:block;}}/*!sc*/
# @media screen and (max-width:399px){.VpUCh{display:none;}}/*!sc*/
# @media screen and (max-width:599px){.VpUCh{display:none;}}/*!sc*/
# .iNkFqh{font-family:'__reithSans_aa0e4a', Helvetica,Arial,sans-serif;font-weight:400;font-size:12px;line-height:14px;text-transform:none;-webkit-text-decoration:none;text-decoration:none;-webkit-letter-spacing:-0.12px;-moz-letter-spacing:-0.12px;-ms-letter-spacing:-0.12px;letter-spacing:-0.12px;color:#545658;}/*!sc*/
# @media screen and (max-width:767px){.iNkFqh{display:none;}}/*!sc*/
# @media screen and (max-width:1007px){.iNkFqh{display:none;}}/*!sc*/
# @media screen and (max-width:1279px){.iNkFqh{display:none;}}/*!sc*/
# @media screen and (max-width:8192px){.iNkFqh{display:none;}}/*!sc*/
# @media screen and (max-width:399px){.iNkFqh{display:block;}}/*!sc*/
# @media screen and (max-width:599px){.iNkFqh{display:block;}}/*!sc*/
# data-styled.g136[id="sc-ec7fe2bd-1"]{content:"eIXzYS,VpUCh,iNkFqh,"}/*!sc*/
# .grtqrQ{color:#545658;font-family:'__reithSans_aa0e4a', Helvetica,Arial,sans-serif;font-weight:400;font-size:12px;line-height:14px;text-transform:none;-webkit-text-decoration:none;text-decoration:none;-webkit-letter-spacing:-0.12px;-moz-letter-spacing:-0.12px;-ms-letter-spacing:-0.12px;letter-spacing:-0.12px;pointer-events:none;}/*!sc*/
# data-styled.g137[id="sc-ec7fe2bd-2"]{content:"grtqrQ,"}/*!sc*/
# .eyPbQc{background-color:#545658;margin:auto 2px;height:16px;width:1px;}/*!sc*/
# .eBlqFD{background-color:#545658;margin:auto 2px;height:16px;width:1px;}/*!sc*/
# @media screen and (max-width:767px){.eBlqFD{display:none;}}/*!sc*/
# @media screen and (max-width:1007px){.eBlqFD{display:none;}}/*!sc*/
# @media screen and (max-width:1279px){.eBlqFD{display:none;}}/*!sc*/
# @media screen and (max-width:8192px){.eBlqFD{display:none;}}/*!sc*/
# @media screen and (max-width:399px){.eBlqFD{display:block;}}/*!sc*/
# @media screen and (max-width:599px){.eBlqFD{display:block;}}/*!sc*/
# data-styled.g138[id="sc-ec7fe2bd-3"]{content:"eyPbQc,eBlqFD,"}/*!sc*/
# .cScezt{background-color:#ffffff;color:#000000;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;justify-items:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;position:absolute;min-width:24px;bottom:0;display:grid;left:0;}/*!sc*/
# @media screen and (max-width:599px){.cScezt{left:0px;display:grid;}}/*!sc*/
# data-styled.g140[id="sc-79ce7c57-0"]{content:"cScezt,"}/*!sc*/
# .jZbybi{-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;height:48px;width:48px;margin:8px;}/*!sc*/
# .jZbybi > svg{height:30px;}/*!sc*/
# @media screen and (max-width:599px){.jZbybi{height:32px;width:32px;margin:4px;}.jZbybi > svg{height:20px;}}/*!sc*/
# .buzvdL{-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;height:32px;width:32px;margin:4px;}/*!sc*/
# .buzvdL > svg{height:20px;}/*!sc*/
# @media screen and (max-width:599px){.buzvdL{height:32px;width:32px;margin:4px;}.buzvdL > svg{height:20px;}}/*!sc*/
# data-styled.g141[id="sc-79ce7c57-1"]{content:"jZbybi,buzvdL,"}/*!sc*/
# .gQGuCj{width:100%;margin-right:0;}/*!sc*/
# @media screen and (max-width:599px){.gQGuCj{margin-right:8px;}}/*!sc*/
# data-styled.g143[id="sc-70eaf3a9-0"]{content:"gQGuCj,"}/*!sc*/
# .cbEjyd{width:100%;}/*!sc*/
# @media screen and (max-width:599px){.cbEjyd{min-height:32px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}}/*!sc*/
# data-styled.g144[id="sc-70eaf3a9-1"]{content:"cbEjyd,iaCYGD,"}/*!sc*/
# .dfMhPx{color:#202224;grid-template-columns:auto auto;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;position:relative;padding-left:2px;margin:0 6px 0 0;display:grid;height:auto;width:auto;color:#EB0000;float:left;grid-gap:2.6px;}/*!sc*/
# .dfMhPx > svg{height:26.7px;width:26.7px;}/*!sc*/
# @media screen and (max-width:599px){.dfMhPx{grid-gap:2.3px;}.dfMhPx > svg{height:23px;}}/*!sc*/
# data-styled.g145[id="sc-70eaf3a9-2"]{content:"dfMhPx,"}/*!sc*/
# .lkuFhf{color:#202224;font-family:'__reithSerif_3e9265', Helvetica,Arial,sans-serif;font-weight:500;font-size:28px;line-height:32px;text-transform:none;-webkit-text-decoration:none;text-decoration:none;-webkit-letter-spacing:-0.56px;-moz-letter-spacing:-0.56px;-ms-letter-spacing:-0.56px;letter-spacing:-0.56px;font-family:'__reithSerif_3e9265', Helvetica,Arial,sans-serif;font-weight:500;font-size:28px;line-height:32px;text-transform:none;-webkit-text-decoration:none;text-decoration:none;-webkit-letter-spacing:-0.56px;-moz-letter-spacing:-0.56px;-ms-letter-spacing:-0.56px;letter-spacing:-0.56px;}/*!sc*/
# @media screen and (max-width:599px){.lkuFhf{font-family:'__reithSerif_3e9265', Helvetica,Arial,sans-serif;font-weight:500;font-size:24px;line-height:28px;text-transform:none;-webkit-text-decoration:none;text-decoration:none;-webkit-letter-spacing:-0.48px;-moz-letter-spacing:-0.48px;-ms-letter-spacing:-0.48px;letter-spacing:-0.48px;}}/*!sc*/
# @media screen and (max-width:599px){.lkuFhf{font-family:'__reithSerif_3e9265', Helvetica,Arial,sans-serif;font-weight:500;font-size:24px;line-height:28px;text-transform:none;-webkit-text-decoration:none;text-decoration:none;-webkit-letter-spacing:-0.48px;-moz-letter-spacing:-0.48px;-ms-letter-spacing:-0.48px;letter-spacing:-0.48px;}}/*!sc*/
# .jwHQEU{color:#202224;font-family:'__reithSerif_3e9265', Helvetica,Arial,sans-serif;font-weight:500;font-size:18px;line-height:22px;text-transform:none;-webkit-text-decoration:none;text-decoration:none;-webkit-letter-spacing:-0.36px;-moz-letter-spacing:-0.36px;-ms-letter-spacing:-0.36px;letter-spacing:-0.36px;}/*!sc*/
# @media screen and (max-width:599px){.jwHQEU{font-family:'__reithSerif_3e9265', Helvetica,Arial,sans-serif;font-weight:500;font-size:18px;line-height:22px;text-transform:none;-webkit-text-decoration:none;text-decoration:none;-webkit-letter-spacing:-0.36px;-moz-letter-spacing:-0.36px;-ms-letter-spacing:-0.36px;letter-spacing:-0.36px;}}/*!sc*/
# .hoFMJk{color:#202224;font-family:'__reithSerif_3e9265', Helvetica,Arial,sans-serif;font-weight:500;font-size:24px;line-height:28px;text-transform:none;-webkit-text-decoration:none;text-decoration:none;-webkit-letter-spacing:-0.48px;-moz-letter-spacing:-0.48px;-ms-letter-spacing:-0.48px;letter-spacing:-0.48px;margin-bottom:12px;font-family:'__reithSerif_3e9265', Helvetica,Arial,sans-serif;font-weight:500;font-size:24px;line-height:28px;text-transform:none;-webkit-text-decoration:none;text-decoration:none;-webkit-letter-spacing:-0.48px;-moz-letter-spacing:-0.48px;-ms-letter-spacing:-0.48px;letter-spacing:-0.48px;}/*!sc*/
# @media screen and (max-width:599px){.hoFMJk{font-family:'__reithSerif_3e9265', Helvetica,Arial,sans-serif;font-weight:500;font-size:20px;line-height:24px;text-transform:none;-webkit-text-decoration:none;text-decoration:none;-webkit-letter-spacing:-0.4px;-moz-letter-spacing:-0.4px;-ms-letter-spacing:-0.4px;letter-spacing:-0.4px;}}/*!sc*/
# @media screen and (max-width:599px){.hoFMJk{margin-bottom:8px;font-family:'__reithSerif_3e9265', Helvetica,Arial,sans-serif;font-weight:500;font-size:18px;line-height:22px;text-transform:none;-webkit-text-decoration:none;text-decoration:none;-webkit-letter-spacing:-0.36px;-moz-letter-spacing:-0.36px;-ms-letter-spacing:-0.36px;letter-spacing:-0.36px;}}/*!sc*/
# data-styled.g146[id="sc-70eaf3a9-3"]{content:"lkuFhf,jwHQEU,hoFMJk,"}/*!sc*/
# .egJcep{color:#202224;font-family:'__reithSans_aa0e4a', Helvetica,Arial,sans-serif;font-weight:700;font-size:28px;line-height:32px;text-transform:uppercase;-webkit-text-decoration:none;text-decoration:none;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;color:#EB0000;-webkit-text-decoration:none !important;text-decoration:none !important;text-transform:uppercase;}/*!sc*/
# @media screen and (max-width:599px){.egJcep{font-family:'__reithSans_aa0e4a', Helvetica,Arial,sans-serif;font-weight:700;font-size:24px;line-height:28px;text-transform:uppercase;-webkit-text-decoration:none;text-decoration:none;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;}}/*!sc*/
# data-styled.g147[id="sc-70eaf3a9-4"]{content:"egJcep,"}/*!sc*/
# .kzVmVM{display:grid;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# .kzVmVM > *{border-top:1px solid #e6e8ea;padding-bottom:12px;padding-right:8px;padding-top:12px;}/*!sc*/
# @media screen and (max-width:767px){.kzVmVM{display:none;}}/*!sc*/
# @media screen and (max-width:1007px){.kzVmVM{display:none;}}/*!sc*/
# @media screen and (max-width:599px){.kzVmVM{display:grid;}}/*!sc*/
# .TBZVQ{display:grid;background-color:transparent;grid-template-columns:repeat(1,1fr);justify-items:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;display:none;justify-items:start;}/*!sc*/
# .TBZVQ > *{border-right:1px solid #e6e8ea;padding-right:8px;padding-left:16px;}/*!sc*/
# .TBZVQ :last-child{border-right:none;}/*!sc*/
# .TBZVQ :first-child{padding-left:0;}/*!sc*/
# @media screen and (max-width:1007px){.TBZVQ{display:grid;}}/*!sc*/
# @media screen and (max-width:599px){.TBZVQ{display:none;}}/*!sc*/
# data-styled.g149[id="sc-46b3209b-0"]{content:"kzVmVM,TBZVQ,"}/*!sc*/
# .hzafvj{color:#202224;font-family:'__reithSerif_3e9265', Helvetica,Arial,sans-serif;font-weight:500;font-size:16px;line-height:20px;text-transform:none;-webkit-text-decoration:none;text-decoration:none;-webkit-letter-spacing:-0.32px;-moz-letter-spacing:-0.32px;-ms-letter-spacing:-0.32px;letter-spacing:-0.32px;}/*!sc*/
# .hzafvj:hover{-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# @media screen and (max-width:599px){.hzafvj{font-family:'__reithSerif_3e9265', Helvetica,Arial,sans-serif;font-weight:500;font-size:16px;line-height:20px;text-transform:none;-webkit-text-decoration:none;text-decoration:none;-webkit-letter-spacing:-0.32px;-moz-letter-spacing:-0.32px;-ms-letter-spacing:-0.32px;letter-spacing:-0.32px;}}/*!sc*/
# data-styled.g150[id="sc-46b3209b-1"]{content:"hzafvj,"}/*!sc*/
# .khWlJB{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;gap:5px;}/*!sc*/
# data-styled.g151[id="sc-46b3209b-2"]{content:"khWlJB,"}/*!sc*/
# .heLzKj{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;width:20px;height:20px;}/*!sc*/
# .heLzKj > svg{height:6px;width:6px;}/*!sc*/
# data-styled.g152[id="sc-46b3209b-3"]{content:"heLzKj,"}/*!sc*/
# .iOkyKB{display:grid;width:100%;padding-bottom:48px;}/*!sc*/
# .iOkyKB:first-of-type{padding-top:24px;}/*!sc*/
# .iOkyKB:last-of-type{padding-bottom:0;}/*!sc*/
# .iOkyKB:first-of-type hr{display:none;}/*!sc*/
# @media screen and (max-width:599px){.iOkyKB{padding-bottom:40px;}}/*!sc*/
# .bPDMPD{display:grid;width:100%;padding-bottom:48px;}/*!sc*/
# .bPDMPD:first-of-type{padding-top:24px;}/*!sc*/
# .bPDMPD:last-of-type{padding-bottom:0;}/*!sc*/
# @media screen and (max-width:599px){.bPDMPD{padding-bottom:40px;}}/*!sc*/
# data-styled.g160[id="sc-86aa332-1"]{content:"iOkyKB,bPDMPD,"}/*!sc*/
# .hWJRZx{max-width:1280px;width:100%;}/*!sc*/
# @media screen and (max-width:8192px){.hWJRZx{margin:0 auto;}}/*!sc*/
# data-styled.g161[id="sc-86aa332-2"]{content:"hWJRZx,"}/*!sc*/
# .jvXgkQ{margin-top:21px;}/*!sc*/
# @media screen and (max-width:1007px){.jvXgkQ{margin-top:24px;}}/*!sc*/
# @media screen and (max-width:399px){.jvXgkQ{margin-top:40px;}}/*!sc*/
# @media screen and (max-width:599px){.jvXgkQ{margin-top:40px;}}/*!sc*/
# data-styled.g162[id="sc-fb2f8b48-0"]{content:"jvXgkQ,"}/*!sc*/
# .Cbpyy{position:relative;}/*!sc*/
# data-styled.g163[id="sc-fb2f8b48-1"]{content:"Cbpyy,"}/*!sc*/
# .enKanj{cursor:pointer;height:44px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;padding:6px 12px;background-color:#e6e8ea;color:#202224;font-family:'__reithSans_aa0e4a', Helvetica,Arial,sans-serif;font-weight:500;font-size:14px;line-height:18px;text-transform:none;-webkit-text-decoration:none;text-decoration:none;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;}/*!sc*/
# .enKanj:hover{background-color:#d2d4d6;}/*!sc*/
# .enKanj[disabled]{cursor:auto;color:#8a8c8e;background-color:#d2d4d6;}/*!sc*/
# .enKanj:active{background-color:#e6e8ea;}/*!sc*/
# data-styled.g164[id="sc-fb2f8b48-2"]{content:"enKanj,"}/*!sc*/
# .dhFqbG{width:24px;height:24px;margin-left:4.5px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;color:#000000;}/*!sc*/
# data-styled.g165[id="sc-fb2f8b48-3"]{content:"dhFqbG,"}/*!sc*/
# .ilVVvM{margin-top:16px;}/*!sc*/
# data-styled.g171[id="sc-db176339-0"]{content:"ilVVvM,"}/*!sc*/
# .iKZcGw{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;-webkit-column-gap:16px;column-gap:16px;row-gap:12px;}/*!sc*/
# data-styled.g172[id="sc-db176339-1"]{content:"iKZcGw,"}/*!sc*/
# .hUXyPv{cursor:pointer;-webkit-text-decoration:none;text-decoration:none;color:#000000;font-family:'__reithSans_aa0e4a', Helvetica,Arial,sans-serif;font-weight:400;font-size:12px;line-height:16px;text-transform:none;-webkit-text-decoration:none;text-decoration:none;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;}/*!sc*/
# .hUXyPv:hover{-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# data-styled.g173[id="sc-db176339-2"]{content:"hUXyPv,"}/*!sc*/
# .hiQReG{margin:0 16px;border-width:0;height:2px;background-color:#3a3c3e;}/*!sc*/
# data-styled.g185[id="sc-e4e102ad-0"]{content:"hiQReG,"}/*!sc*/
# .iUmCoV{-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;margin-bottom:24px;margin-top:12px;padding:0 16px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}/*!sc*/
# @media screen and (max-width:599px){.iUmCoV{margin-bottom:16px;margin-top:8px;}}/*!sc*/
# data-styled.g186[id="sc-e4e102ad-1"]{content:"iUmCoV,"}/*!sc*/
# .fFJFOc{font-family:'__reithSerif_3e9265', Helvetica,Arial,sans-serif;font-weight:700;font-size:18px;line-height:22px;text-transform:none;-webkit-text-decoration:none;text-decoration:none;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;color:#202224;}/*!sc*/
# ...
#        <div>
#         <button class="sc-f67e2d82-2 hqnDbU" data-testid="level1NavButton-/travel">
#          <span class="sc-f67e2d82-3 lhGSRJ" data-testid="level1NavText-/travel">
#           Travel
#          </span>
#          <div class="sc-f67e2d82-1 ougvF" data-testid="menuItem-ChevronIconWrapper-/travel">
#           <svg category="arrows" class="sc-200855d3-0 hTnynj" data-testid="menuItem-ChevronIcon-/travel" height="1em" icon="chevron-down" viewbox="0 0 32 32" width="1em">
#            <path d="M17.7 22.6.9 4.2v6.7L16 27.8 31.1 11V4.3L14.3 22.6h3.4zm0 0L.9 4.2v6.7L16 27.8 31.1 11V4.3L14.3 22.6h3.4z">
#            </path>
#           </svg>
#          </div>
#         </button>
#         <div class="sc-f67e2d82-4 dFtMiT" data-testid="level1NavContent-/travel">
#          <div class="sc-f67e2d82-5 fYjbNv" data-testid="navigationPanel-navItem-level2">
#           <div class="sc-4befc967-0 bUlrPj">
#            <a class="sc-4befc967-1 gzOvMy" data-testid="internal-link" href="/travel">
#             <button class="sc-f67e2d82-2 cPpMFZ" data-testid="level2NavButton-/travel/travel">
#              <span class="sc-f67e2d82-3 lhGSRJ" data-testid="level2NavText-/travel/travel">
#               Travel
#              </span>
#             </button>
#            </a>
#           </div>
#          </div>
#          <div class="sc-f67e2d82-5 fYjbNv" data-testid="navigationPanel-navItem-level2">
#           <div class="sc-4befc967-0 bUlrPj">
#            <a class="sc-4befc967-1 gzOvMy" data-testid="internal-link" href="/travel/destinations">
#             <button class="sc-f67e2d82-2 cPpMFZ" data-testid="level2NavButton-/travel/destinations">
#              <span class="sc-f67e2d82-3 lhGSRJ" data-testid="level2NavText-/travel/destinations">
#               Destinations
#              </span>
#             </button>
#            </a>
#           </div>
#          </div>
#          <div class="sc-f67e2d82-5 fYjbNv" data-testid="navigationPanel-navItem-level2">
#           <div class="sc-4befc967-0 bUlrPj">
#            <a class="sc-4befc967-1 gzOvMy" data-testid="internal-link" href="/travel/worlds-table">
#             <button class="sc-f67e2d82-2 cPpMFZ" data-testid="level2NavButton-/travel/worlds-table">
#              <span class="sc-f67e2d82-3 lhGSRJ" data-testid="level2NavText-/travel/worlds-table">
#               World’s Table
#              </span>
#             </button>
#            </a>
#           </div>
#          </div>
#          <div class="sc-f67e2d82-5 fYjbNv" data-testid="navigationPanel-navItem-level2">
#           <div class="sc-4befc967-0 bUlrPj">
#            <a class="sc-4befc967-1 gzOvMy" data-testid="internal-link" href="/travel/cultural-experiences">
#             <button class="sc-f67e2d82-2 cPpMFZ" data-testid="level2NavButton-/travel/cultural-experiences">
#              <span class="sc-f67e2d82-3 lhGSRJ" data-testid="level2NavText-/travel/cultural-experiences">
#               Culture &amp; Experiences
#              </span>
#             </button>
#            </a>
#           </div>
#          </div>
#          <div class="sc-f67e2d82-5 fYjbNv" data-testid="navigationPanel-navItem-level2">
#           <div class="sc-4befc967-0 bUlrPj">
#            <a class="sc-4befc967-1 gzOvMy" data-testid="internal-link" href="/travel/adventures">
#             <button class="sc-f67e2d82-2 cPpMFZ" data-testid="level2NavButton-/travel/adventures">
#              <span class="sc-f67e2d82-3 lhGSRJ" data-testid="level2NavText-/travel/adventures">
#               Adventures
#              </span>
#             </button>
#            </a>
#           </div>
#          </div>
#          <div class="sc-f67e2d82-5 fYjbNv" data-testid="navigationPanel-navItem-level2">
#           <div class="sc-4befc967-0 bUlrPj">
#            <a class="sc-4befc967-1 gzOvMy" data-testid="internal-link" href="/travel/specialist">
#             <button class="sc-f67e2d82-2 cPpMFZ" data-testid="level2NavButton-/travel/specialist">
#              <span class="sc-f67e2d82-3 lhGSRJ" data-testid="level2NavText-/travel/specialist">
#               The SpeciaList
#              </span>
#             </button>
#            </a>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="sc-f67e2d82-5 hpFPKZ" data-testid="navigationPanel-navItem-level1">
#        <div>
#         <button class="sc-f67e2d82-2 hqnDbU" data-testid="level1NavButton-/future-planet">
#          <span class="sc-f67e2d82-3 lhGSRJ" data-testid="level1NavText-/future-planet">
#           Earth
#          </span>
#          <div class="sc-f67e2d82-1 ougvF" data-testid="menuItem-ChevronIconWrapper-/future-planet">
#           <svg category="arrows" class="sc-200855d3-0 hTnynj" data-testid="menuItem-ChevronIcon-/future-planet" height="1em" icon="chevron-down" viewbox="0 0 32 32" width="1em">
#            <path d="M17.7 22.6.9 4.2v6.7L16 27.8 31.1 11V4.3L14.3 22.6h3.4zm0 0L.9 4.2v6.7L16 27.8 31.1 11V4.3L14.3 22.6h3.4z">
#            </path>
#           </svg>
#          </div>
#         </button>
#         <div class="sc-f67e2d82-4 dFtMiT" data-testid="level1NavContent-/future-planet">
#          <div class="sc-f67e2d82-5 fYjbNv" data-testid="navigationPanel-navItem-level2">
#           <div class="sc-4befc967-0 bUlrPj">
#            <a class="sc-4befc967-1 gzOvMy" data-testid="internal-link" href="/future-planet">
#             <button class="sc-f67e2d82-2 cPpMFZ" data-testid="level2NavButton-/future-planet/future-planet">
#              <span class="sc-f67e2d82-3 lhGSRJ" data-testid="level2NavText-/future-planet/future-planet">
#               Earth
#              </span>
#             </button>
#            </a>
#           </div>
#          </div>
#          <div class="sc-f67e2d82-5 fYjbNv" data-testid="navigationPanel-navItem-level2">
#           <div class="sc-4befc967-0 bUlrPj">
#            <a class="sc-4befc967-1 gzOvMy" data-testid="internal-link" href="/future-planet/natural-wonders">
#             <button class="sc-f67e2d82-2 cPpMFZ" data-testid="level2NavButton-/future-planet/natural-wonders">
#              <span class="sc-f67e2d82-3 lhGSRJ" data-testid="level2NavText-/future-planet/natural-wonders">
#               Natural Wonders
#              </span>
#             </button>
#            </a>
#           </div>
#          </div>
#          <div class="sc-f67e2d82-5 fYjbNv" data-testid="navigationPanel-navItem-level2">
#           <div class="sc-4befc967-0 bUlrPj">
#            <a class="sc-4befc967-1 gzOvMy" data-testid="internal-link" href="/future-planet/weather-science">
#             <button class="sc-f67e2d82-2 cPpMFZ" data-testid="level2NavButton-/future-planet/weather-science">
#              <span class="sc-f67e2d82-3 lhGSRJ" data-testid="level2NavText-/future-planet/weather-science">
#               Weather &amp; Science
#              </span>
#             </button>
#            </a>
#           </div>
#          </div>
#          <div class="sc-f67e2d82-5 fYjbNv" data-testid="navigationPanel-navItem-level2">
#           <div class="sc-4befc967-0 bUlrPj">
#            <a class="sc-4befc967-1 gzOvMy" data-testid="internal-link" href="/future-planet/solutions">
#             <button class="sc-f67e2d82-2 cPpMFZ" data-testid="level2NavButton-/future-planet/solutions">
#              <span class="sc-f67e2d82-3 lhGSRJ" data-testid="level2NavText-/future-planet/solutions">
#               Climate Solutions
#              </span>
#             </button>
#            </a>
#           </div>
#          </div>
#          <div class="sc-f67e2d82-5 fYjbNv" data-testid="navigationPanel-navItem-level2">
#           <div class="sc-4befc967-0 bUlrPj">
#            <a class="sc-4befc967-1 gzOvMy" data-testid="internal-link" href="/future-planet/sustainable-business">
#             <button class="sc-f67e2d82-2 cPpMFZ" data-testid="level2NavButton-/future-planet/sustainable-business">
#              <span class="sc-f67e2d82-3 lhGSRJ" data-testid="level2NavText-/future-planet/sustainable-business">
#               Sustainable Business
#              </span>
#             </button>
#            </a>
#           </div>
#          </div>
#          <div class="sc-f67e2d82-5 fYjbNv" data-testid="navigationPanel-navItem-level2">
#           <div class="sc-4befc967-0 bUlrPj">
#            <a class="sc-4befc967-1 gzOvMy" data-testid="internal-link" href="/future-planet/green-living">
#             <button class="sc-f67e2d82-2 cPpMFZ" data-testid="level2NavButton-/future-planet/green-living">
#              <span class="sc-f67e2d82-3 lhGSRJ" data-testid="level2NavText-/future-planet/green-living">
#               Green Living
#              </span>
#             </button>
#            </a>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="sc-f67e2d82-5 hpFPKZ" data-testid="navigationPanel-navItem-level1">
#        <div class="sc-4befc967-0 bUlrPj">
#         <a class="sc-4befc967-1 gzOvMy" data-testid="internal-link" href="/video">
#          <button class="sc-f67e2d82-2 hqnDbU" data-testid="level1NavButton-/video">
#           <span class="sc-f67e2d82-3 lhGSRJ" data-testid="level1NavText-/video">
#            Video
#           </span>
#          </button>
#         </a>
#        </div>
#       </div>
#       <div class="sc-f67e2d82-5 hpFPKZ" data-testid="navigationPanel-navItem-level1">
#        <div>
#         <button class="sc-f67e2d82-2 hqnDbU" data-testid="level1NavButton-/live">
#          <span class="sc-f67e2d82-3 lhGSRJ" data-testid="level1NavText-/live">
#           Live
#          </span>
#          <div class="sc-f67e2d82-1 ougvF" data-testid="menuItem-ChevronIconWrapper-/live">
#           <svg category="arrows" class="sc-200855d3-0 hTnynj" data-testid="menuItem-ChevronIcon-/live" height="1em" icon="chevron-down" viewbox="0 0 32 32" width="1em">
#            <path d="M17.7 22.6.9 4.2v6.7L16 27.8 31.1 11V4.3L14.3 22.6h3.4zm0 0L.9 4.2v6.7L16 27.8 31.1 11V4.3L14.3 22.6h3.4z">
#            </path>
#           </svg>
#          </div>
#         </button>
#         <div class="sc-f67e2d82-4 dFtMiT" data-testid="level1NavContent-/live">
#          <div class="sc-f67e2d82-5 fYjbNv" data-testid="navigationPanel-navItem-level2">
#           <div class="sc-4befc967-0 bUlrPj">
#            <a class="sc-4befc967-1 gzOvMy" data-testid="internal-link" href="/live">
#             <button class="sc-f67e2d82-2 cPpMFZ" data-testid="level2NavButton-/live/live">
#              <span class="sc-f67e2d82-3 lhGSRJ" data-testid="level2NavText-/live/live">
#               Live
#              </span>
#             </button>
#            </a>
#           </div>
#          </div>
#          <div class="sc-f67e2d82-5 fYjbNv" data-testid="navigationPanel-navItem-level2">
#           <div class="sc-4befc967-0 bUlrPj">
#            <a class="sc-4befc967-1 gzOvMy" data-testid="internal-link" href="/live/news">
#             <button class="sc-f67e2d82-2 cPpMFZ" data-testid="level2NavButton-/live/news">
#              <span class="sc-f67e2d82-3 lhGSRJ" data-testid="level2NavText-/live/news">
#               Live News
#              </span>
#             </button>
#            </a>
#           </div>
#          </div>
#          <div class="sc-f67e2d82-5 fYjbNv" data-testid="navigationPanel-navItem-level2">
#           <div class="sc-4befc967-0 bUlrPj">
#            <a class="sc-4befc967-1 gzOvMy" data-testid="internal-link" href="/live/sport">
#             <button class="sc-f67e2d82-2 cPpMFZ" data-testid="level2NavButton-/live/sport">
#              <span class="sc-f67e2d82-3 lhGSRJ" data-testid="level2NavText-/live/sport">
#               Live Sport
#              </span>
#             </button>
#            </a>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="sc-f67e2d82-5 hpFPKZ" data-testid="navigationPanel-navItem-level1">
#        <a class="sc-4befc967-1 gzOvMy" href="https://www.bbc.co.uk/sounds" target="_self">
#         <button class="sc-f67e2d82-2 hqnDbU" data-testid="level1NavButton-https://www.bbc.co.uk/sounds">
#          <span data-testid="level1NavText-https://www.bbc.co.uk/sounds">
#           Audio
#          </span>
#         </button>
#        </a>
#       </div>
#      </div>
#     </div>
#     <!--$!-->
#     <!--/$-->
#    </main>
#   </div>
#   <script id="__NEXT_DATA__" type="application/json">
#    {"props":{"pageProps":{"authInfo":{"signInUrl":"https://session.bbc.com/session","signOutUrl":"https://account.bbc.com/signout","registerUrl":"https://session.bbc.com/session?action=register","statusUrl":"https://account.bbc.com/account","idSignedInCookieName":"ckns_id","accessTokenRefreshUrl":"https://session.bbc.com/session?ptrt=https%3A%2F%2Fsession.bbc.com%2Fsession%2Fannounce","accessTokenExpiredAt":0,"displayName":""},"mainNavigation":[{"id":"667d8ba9-ecc3-4b9b-88c2-613c2c5ee911","title":"Home","isSpecial":false,"slug":"home","path":"/home","externalTarget":"_self","subMenus":[]},{"id":"d0731524-f6da-42c7-80b5-f759e190f219","title":"News","isSpecial":false,"slug":"news","path":"/news","externalTarget":"_self","subMenus":[{"id":"767df23c-93da-4a2d-9e43-9e0cbfd8571d","title":"News","isSpecial":false,"slug":"news","path":"/news","externalTarget":"_self","subMenus":[]},{"id":"5e5cd8cf-5aed-41f1-92a2-60db9bc12173","title":"Israel-Gaza War","isSpecial":false,"slug":"israel-gaza-war","path":"/news/topics/c2vdnvdg6xxt","externalTarget":"_self","subMenus":[]},{"id":"e135f9bc-1c9b-4f05-8b45-b97c5ddeae5e","title":"War in Ukraine","isSpecial":false,"slug":"war-in-ukraine","path":"/news/war-in-ukraine","externalTarget":"_self","subMenus":[]},{"id":"345ce1af-35c4-4b26-9efd-3c3753bef12e","title":"World","isSpecial":false,"slug":"world","path":"/news/world","externalTarget":"_self","subMenus":[{"id":"dc7e63c6-9df9-4049-a28b-3458a0a10755","title":"World","isSpecial":false,"slug":"world","path":"/news/world","externalTarget":"_self","subMenus":[]},{"id":"d6d53354-ca51-428e-adbd-c4c5f59a9bf4","title":"Africa","isSpecial":false,"slug":"africa","path":"/news/world/africa","externalTarget":"_self","subMenus":[]},{"id":"3ebf2114-9c3c-4a41-9682-215afe25f0fb","title":"Asia","isSpecial":false,"slug":"asia","path":"/news/world/asia","externalTarget":"_self","subMenus":[{"id":"1aefa09b-d45f-4a40-a6b8-484aba029da7","title":"China","isSpecial":false,"slug":"china","path":"/news/world/asia/china","externalTarget":"_self","subMenus":[]},{"id":"87799cc2-9cfd-4051-b269-55569605e757","title":"India","isSpecial":false,"slug":"india","path":"/news/world/asia/india","externalTarget":"_self","subMenus":[]}]},{"id":"25edefb3-ab95-4a52-adf8-babf8c34d202","title":"Australia","isSpecial":false,"slug":"australia","path":"/news/world/australia","externalTarget":"_self","subMenus":[]},{"id":"d0f403f2-ee4a-421f-b42d-9388dbc32d7b","title":"Europe","isSpecial":false,"slug":"europe","path":"/news/world/europe","externalTarget":"_self","subMenus":[]},{"id":"c47bddb3-ccd3-4eaf-8031-12aae8866a78","title":"Latin America","isSpecial":false,"slug":"latin-america","path":"/news/world/latin_america","externalTarget":"_self","subMenus":[]},{"id":"ad01786e-8487-4931-b202-b87106d758d6","title":"Middle East","isSpecial":false,"slug":"middle-east","path":"/news/world/middle_east","externalTarget":"_self","subMenus":[]}]},{"id":"318a8f67-1d9d-4e74-905e-22019acfaf0c","title":"US \u0026 Canada","isSpecial":false,"slug":"us-canada","path":"/news/us-canada","externalTarget":"_self","subMenus":[]},{"id":"d2617d2c-c291-4f62-aad7-882c5f9e96e2","title":"UK","isSpecial":false,"slug":"uk","path":"/news/uk","externalTarget":"_self","subMenus":[]},{"id":"426a47d4-e3ad-4b65-a09f-6e40756be92a","title":"In Pictures","isSpecial":false,"slug":"in-pictures","path":"/news/in_pictures","externalTarget":"_self","subMenus":[]},{"id":"586b0c53-c078-4b3f-a9e5-c6d6774d05ab","title":"BBC Verify","isSpecial":false,"slug":"bbc-verify","path":"/news/reality_check","externalTarget":"_self","subMenus":[]}]},{"id":"f92a2a22-8280-4bee-b0c0-c8b747e95bef","title":"Sport","isSpecial":false,"slug":"sport","path":"/sport","externalTarget":"_self","subMenus":[]},{"id":"02f2e67a-8ef3-4630-a933-686c71e84fad","title":"Business","isSpecial":false,"slug":"business","path":"/business","externalTarget":"_self","subMenus":[{"id":"b3457121-7317-4d9f-b8be-c5b4e58a3ed6","title":"Business","isSpecial":false,"slug":"business","path ...
#   </script>
#  </body>
# </html>

# %%
cont2 = soup.find_all(attrs={'data-testid':'card-text-wrapper'})
cont2[1].find(attrs={'data-testid':'card-headline'}).get_text()
cont2[1].find(attrs={'data-testid':'card-description'}).get_text()


titulos = []
descripciones = []
for e in cont2:
  titulos.append(e.find(attrs={'data-testid':'card-headline'}).get_text())
  descripciones.append(e.find(attrs={'data-testid':'card-description'}).get_text())
df = pd.DataFrame({"titulo":titulos, "descripcion": descripciones})
df
# Out:
#                                                titulo  \
# 0   Hamas says pause in Gaza fighting to begin at ...
# 1                 Sam Altman to return as OpenAI boss
# 2   ‘How I got dangerous chat site Omegle closed d...
# 3   Russian authorities crack down on abortion access
# 4   Pilot sentenced for decapitating skydiver with...
# 5                 Sam Altman to return as OpenAI boss
# 6   Russian actress killed in strike while perform...
# 7     Drilling resumes to save trapped Indian workers
# 8   ‘How I got dangerous chat site Omegle closed d...
# 9   S Korea suspends parts of military deal with N...
# 10  Ghana MP sorry for mocking footballer Harry Ma...
# 11   Dutch vote for new leaders in neck-and-neck race
# 12    China accused of closing and destroying mosques
# 13  US set for busiest travel day as weather fears...
# 14  Watch: Blackpink's shock as King name-checks them
# 15  How lockdown inspired fight against period pov...
# 16           Video shows car mauled by a trapped bear
# 17  Biden confuses Britney and Taylor at Turkey ce...
# 18  MPs set off coloured smoke flares in Albanian ...
# 19  Are we any closer to solving JFK's assassination?
# 20      Fighting climate change with 100ft ice towers
# 21  Indian captain who lost the World Cup but won ...
# 22  'Cheats and parasites': Behind East Africa's o...
# 23                    Who is the new boss of Binance?
# 24  This is what America's busiest travel days loo...
# 25       Gaza Strip in maps: Life in Gaza under siege
# 26  'Blackout Wednesday' prompts drink-driving war...
# 27   Dutch vote for new leaders in neck-and-neck race
# 28  Stories of the hostages taken by Hamas from Is...
# 29  Hostages deal raises hopes and fears for families
# 30  Russian authorities crack down on abortion access
# 31  US set for busiest travel day as weather fears...
# 32  Biden pardons Thanksgiving turkeys on his birt...
#
#                                           descripcion
# 0   Israel has confirmed a four-day pause in fight...
# 1   The in principle agreement involves a new boar...
# 2   "Alice" speaks exclusively to the BBC after he...
# 3   Authorities in Russia are aiming to limit abor...
# 4   Nicolas Galy, 40, died after being struck by t...
# 5   The in principle agreement involves a new boar...
# 6   Around 20 Russian soldiers were killed in the ...
# 7   The 41 workers got stuck when an under-constru...
# 8   "Alice" speaks exclusively to the BBC after he...
# 9   South Korea will resume surveillance flights a...
# 10  Isaac Adongo compared his vice-president's eco...
# 11  The head of the centre right, Dilan Yesilgöz, ...
# 12  The crackdown is part of a "systematic effort"...
# 13  Wintry conditions in the east are forecast to ...
# 14  The K-pop stars were at Buckingham Palace on t...
# 15  Inside a project tackling period poverty, with...
# 16  Wildlife officials in Colorado say the animal ...
# 17  The US president pardoned 'Liberty' and 'Bell'...
# 18  The smoke flares and fire were part of an atte...
# 19  Recent revelations by an ex-Secret Service age...
# 20  The people of Ladakh in the Indian Himalayas h...
# 21  Rohit Sharma led a cricket team that was undef...
# 22  Landlocked Uganda has accused Kenyan middlemen...
# 23  Richard Teng rapidly climbed the ranks after j...
# 24  Officials expect nearly 30 million passengers ...
# 25  Find out more about what it is like to live in...
# 26  The night before Thanksgiving brings a spike o...
# 27  The head of the centre right, Dilan Yesilgöz, ...
# 28  From elderly grandparents to young children, t...
# 29  Relatives of those held anxiously wait to see ...
# 30  Authorities in Russia are aiming to limit abor...
# 31  Wintry conditions in the east are forecast to ...
# 32  The US president pardoned Liberty and Bell, an...

# %% [markdown]
# [Doc Selenium](https://aprendepython.es/pypi/scraping/selenium/)
